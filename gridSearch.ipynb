# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter
import re

PATH = "data\sherlock-holm.es_stories_plain-text_advs.txt"

# Read the text file
with open(PATH, 'r', encoding='utf-8') as file:
    text = file.read()

# %%
# Tokenize the text
def tokenize(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    words = text.split()
    return words

tokens = tokenize(text)
word_counts = Counter(tokens)
vocab = sorted(word_counts, key=word_counts.get, reverse=True)
word_to_index = {word: index + 1 for index, word in enumerate(vocab)}
index_to_word = {index + 1: word for index, word in enumerate(vocab)}
total_words = len(word_to_index) + 1

# %%
# Create input-output pairs
input_sequences = []
for line in text.split('\n'):
    token_list = [word_to_index[word] for word in tokenize(line) if word in word_to_index]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
# Pad the sequences
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array([np.pad(seq, (max_sequence_len - len(seq), 0), mode='constant') for seq in input_sequences])

# %%
# Split the sequences into input (X) and output (y)
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# Convert output to one-hot encoded vectors
y = np.array(torch.nn.functional.one_hot(torch.tensor(y, dtype=torch.long), num_classes=total_words))

# %%
# Create a custom Dataset class
class TextDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = TextDataset(X, y)

# Split dataset into training and validation sets (90% training, 10% validation)
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# Define the model
class NextWordPredictor(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim):
        super(NextWordPredictor, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc(x)
        return x

model = NextWordPredictor(total_words, 200, 256, total_words).cuda()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.base import BaseEstimator, ClassifierMixin

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class PyTorchModel(BaseEstimator, ClassifierMixin):
    def __init__(self, vocab_size, embed_dim=100, hidden_dim=150, output_dim=None, lr=0.001, epochs=10):
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.lr = lr
        self.epochs = epochs
        self.model = NextWordPredictor(vocab_size, embed_dim, hidden_dim, output_dim).to(device)
        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.lr)

    def fit(self, X, y):
        dataset = TextDataset(X, y)
        train_size = int(0.9 * len(dataset))
        val_size = len(dataset) - train_size
        train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
        train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
        self.model.train()
        for epoch in range(self.epochs):
            for inputs, labels in train_dataloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels.argmax(dim=1))
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
        return self

    def predict(self, X):
        self.model.eval()
        with torch.no_grad():
            outputs = self.model(torch.tensor(X, dtype=torch.long).to(device))
            return outputs.argmax(dim=1).cpu().numpy()

    def score(self, X, y):
        self.model.eval()
        correct_predictions = 0
        total_predictions = 0
        with torch.no_grad():
            outputs = self.model(torch.tensor(X, dtype=torch.long).to(device))
            predicted = outputs.argmax(dim=1).cpu()
            actual = torch.tensor(y, dtype=torch.long).cpu()
            correct_predictions = (predicted == actual).sum().item()
            total_predictions = len(y)
        return correct_predictions / total_predictions


# Define the parameter grid
param_grid = {
    'embed_dim': [50, 100, 200],
    'hidden_dim': [128, 256, 512],
    'lr': [0.001, 0.0001]
}

# Perform grid search
grid_search = GridSearchCV(PyTorchModel(vocab_size=total_words, output_dim=total_words), param_grid, cv=3, scoring='accuracy')
grid_search.fit(X, y)

print("Best parameters found: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)

# After finding the best parameters, you can train the final model with them
#best_params = grid_search.best_params_
#best_model = PyTorchModel(vocab_size=total_words, output_dim=total_words, **best_params)
#best_model.fit(X, y)
# Out:
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
# ...
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "s:\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#            ^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 192, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 221, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "s:\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# s:\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# Best parameters found:  {'embed_dim': 50, 'hidden_dim': 128, 'lr': 0.001}
# Best score:  nan

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# Coda setting
import torch
print(f"Is coda avialable: {torch.cuda.is_available()}")

a=torch.FloatTensor([1.0,2.0]).cuda()
a.device
torch.manual_seed(32)


next(model.parameters()).is_cuda
gpumodel = model.cuda()
# Out:
# Is coda avialable: True

# %%
import torch

# Verifica si hay una GPU disponible y, si no, usa la CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Mueve el modelo al dispositivo
model.to(device)

# Suponiendo que el criterio y el optimizador se hayan definido previamente
criterion = criterion.to(device)

epochs = 200
for epoch in range(epochs):
    model.train()
    for inputs, labels in train_dataloader:
        # Mueve los datos de entrada y las etiquetas al dispositivo
        inputs, labels = inputs.to(device), labels.to(device)

        # Realiza las predicciones
        outputs = model(inputs)

        # Calcula la pérdida
        loss = criterion(outputs, labels.argmax(dim=1))

        # Optimiza el modelo
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')

# Guarda el estado del modelo
torch.save(model.state_dict(), "model_state.pth")
# Out:
# Epoch 1/200, Loss: 6.5344085693359375
# Epoch 2/200, Loss: 4.913583278656006
# Epoch 3/200, Loss: 5.6329474449157715
# Epoch 4/200, Loss: 4.490845680236816
# Epoch 5/200, Loss: 2.9339778423309326
# Epoch 6/200, Loss: 2.1444764137268066
# Epoch 7/200, Loss: 2.306044101715088
# Epoch 8/200, Loss: 2.8308041095733643
# Epoch 9/200, Loss: 1.9185158014297485
# Epoch 10/200, Loss: 1.5864721536636353
# Epoch 11/200, Loss: 1.256124496459961
# Epoch 12/200, Loss: 0.9370671510696411
# Epoch 13/200, Loss: 1.331300973892212
# Epoch 14/200, Loss: 0.9904576539993286
# Epoch 15/200, Loss: 1.1658934354782104
# Epoch 16/200, Loss: 0.8523066639900208
# Epoch 17/200, Loss: 0.6752649545669556
# Epoch 18/200, Loss: 0.4826428294181824
# Epoch 19/200, Loss: 0.3789665400981903
# Epoch 20/200, Loss: 0.5691863298416138
# Epoch 21/200, Loss: 0.5297027230262756
# Epoch 22/200, Loss: 0.22712139785289764
# Epoch 23/200, Loss: 0.5868541598320007
# Epoch 24/200, Loss: 0.36076849699020386
# Epoch 25/200, Loss: 1.021597146987915
# Epoch 26/200, Loss: 0.3002721667289734
# Epoch 27/200, Loss: 0.5682441592216492
# Epoch 28/200, Loss: 0.09550870954990387
# Epoch 29/200, Loss: 0.254242479801178
# Epoch 30/200, Loss: 0.6439918875694275
# Epoch 31/200, Loss: 0.5558394193649292
# Epoch 32/200, Loss: 0.33186405897140503
# Epoch 33/200, Loss: 0.8322036862373352
# Epoch 34/200, Loss: 0.4903058111667633
# Epoch 35/200, Loss: 0.5215122699737549
# Epoch 36/200, Loss: 0.6447333097457886
# Epoch 37/200, Loss: 0.6729515790939331
# Epoch 38/200, Loss: 0.523253321647644
# Epoch 39/200, Loss: 1.0330675840377808
# Epoch 40/200, Loss: 0.44121551513671875
# Epoch 41/200, Loss: 0.8214567303657532
# Epoch 42/200, Loss: 0.4270612299442291
# Epoch 43/200, Loss: 0.338919073343277
# Epoch 44/200, Loss: 0.5183441042900085
# Epoch 45/200, Loss: 0.5997635722160339
# Epoch 46/200, Loss: 0.2494158297777176
# Epoch 47/200, Loss: 0.21013016998767853
# Epoch 48/200, Loss: 0.6655793786048889
# Epoch 49/200, Loss: 0.4991639256477356
# Epoch 50/200, Loss: 0.7074548006057739
# Epoch 51/200, Loss: 0.37265607714653015
# Epoch 52/200, Loss: 0.5248693227767944
# Epoch 53/200, Loss: 0.18962028622627258
# Epoch 54/200, Loss: 0.31102296710014343
# Epoch 55/200, Loss: 0.6588267087936401
# Epoch 56/200, Loss: 0.3947505056858063
# Epoch 57/200, Loss: 0.22101429104804993
# Epoch 58/200, Loss: 0.5952314138412476
# Epoch 59/200, Loss: 0.41960492730140686
# Epoch 60/200, Loss: 0.07576540857553482
# Epoch 61/200, Loss: 0.26809462904930115
# Epoch 62/200, Loss: 0.29712358117103577
# Epoch 63/200, Loss: 0.8105182647705078
# Epoch 64/200, Loss: 0.05105046555399895
# Epoch 65/200, Loss: 0.1434277594089508
# Epoch 66/200, Loss: 0.16661156713962555
# Epoch 67/200, Loss: 0.6705571413040161
# Epoch 68/200, Loss: 0.22935709357261658
# Epoch 69/200, Loss: 0.31786227226257324
# Epoch 70/200, Loss: 0.16329863667488098
# Epoch 71/200, Loss: 0.3954087495803833
# Epoch 72/200, Loss: 0.7757426500320435
# Epoch 73/200, Loss: 0.6541849374771118
# Epoch 74/200, Loss: 0.1628272533416748
# Epoch 75/200, Loss: 0.10399655997753143
# Epoch 76/200, Loss: 0.6209762692451477
# Epoch 77/200, Loss: 0.4194672703742981
# Epoch 78/200, Loss: 0.26583054661750793
# Epoch 79/200, Loss: 0.5992173552513123
# Epoch 80/200, Loss: 0.1491444855928421
# Epoch 81/200, Loss: 0.5642392039299011
# Epoch 82/200, Loss: 0.5012600421905518
# Epoch 83/200, Loss: 0.4770747721195221
# Epoch 84/200, Loss: 0.33579573035240173
# Epoch 85/200, Loss: 0.29524144530296326
# Epoch 86/200, Loss: 0.4254390597343445
# Epoch 87/200, Loss: 0.3345800042152405
# Epoch 88/200, Loss: 0.10454095900058746
# Epoch 89/200, Loss: 0.14353995025157928
# Epoch 90/200, Loss: 0.5456243753433228
# Epoch 91/200, Loss: 0.3129945695400238
# Epoch 92/200, Loss: 0.7348690032958984
# Epoch 93/200, Loss: 0.454741895198822
# Epoch 94/200, Loss: 0.5432388186454773
# Epoch 95/200, Loss: 0.43614402413368225
# Epoch 96/200, Loss: 0.08331295102834702
# Epoch 97/200, Loss: 0.2616942226886749
# Epoch 98/200, Loss: 1.0352563858032227
# Epoch 99/200, Loss: 0.3171343207359314
# Epoch 100/200, Loss: 0.10857957601547241
# Epoch 101/200, Loss: 0.5388574600219727
# Epoch 102/200, Loss: 0.5740914344787598
# Epoch 103/200, Loss: 0.13342756032943726
# Epoch 104/200, Loss: 0.289032518863678
# Epoch 105/200, Loss: 0.48128634691238403
# Epoch 106/200, Loss: 0.8174182772636414
# Epoch 107/200, Loss: 0.34812813997268677
# Epoch 108/200, Loss: 0.3742341101169586
# Epoch 109/200, Loss: 0.563391387462616
# Epoch 110/200, Loss: 0.2684025168418884
# Epoch 111/200, Loss: 0.7066750526428223
# Epoch 112/200, Loss: 0.3075631260871887
# Epoch 113/200, Loss: 0.28927308320999146
# Epoch 114/200, Loss: 1.0853725671768188
# Epoch 115/200, Loss: 0.513927698135376
# Epoch 116/200, Loss: 0.03921021893620491
# Epoch 117/200, Loss: 0.6347615122795105
# Epoch 118/200, Loss: 0.4008840024471283
# Epoch 119/200, Loss: 0.6472028493881226
# Epoch 120/200, Loss: 0.3174878656864166
# Epoch 121/200, Loss: 0.2931738495826721
# Epoch 122/200, Loss: 0.6103070974349976
# Epoch 123/200, Loss: 0.9522612690925598
# Epoch 124/200, Loss: 0.49921226501464844
# Epoch 125/200, Loss: 0.48033133149147034
# Epoch 126/200, Loss: 0.028015365824103355
# Epoch 127/200, Loss: 0.03621743619441986
# Epoch 128/200, Loss: 0.7854660749435425
# Epoch 129/200, Loss: 0.3620482087135315
# Epoch 130/200, Loss: 0.588180661201477
# Epoch 131/200, Loss: 0.5577971935272217
# Epoch 132/200, Loss: 0.6058312058448792
# Epoch 133/200, Loss: 0.27868950366973877
# Epoch 134/200, Loss: 0.573725700378418
# Epoch 135/200, Loss: 0.36208683252334595
# Epoch 136/200, Loss: 0.22743335366249084
# Epoch 137/200, Loss: 0.33964163064956665
# Epoch 138/200, Loss: 0.6264255046844482
# Epoch 139/200, Loss: 0.24985678493976593
# Epoch 140/200, Loss: 0.9079656600952148
# Epoch 141/200, Loss: 0.30101677775382996
# Epoch 142/200, Loss: 0.41573435068130493
# Epoch 143/200, Loss: 0.7639655470848083
# Epoch 144/200, Loss: 0.17344580590724945
# Epoch 145/200, Loss: 0.2477712333202362
# Epoch 146/200, Loss: 0.3003659248352051
# Epoch 147/200, Loss: 1.1247875690460205
# Epoch 148/200, Loss: 0.3417498469352722
# Epoch 149/200, Loss: 0.3424730896949768
# Epoch 150/200, Loss: 0.32825690507888794
# Epoch 151/200, Loss: 0.2453109472990036
# Epoch 152/200, Loss: 0.38074278831481934
# Epoch 153/200, Loss: 0.6295589208602905
# Epoch 154/200, Loss: 0.23404636979103088
# Epoch 155/200, Loss: 0.015397797338664532
# Epoch 156/200, Loss: 0.33682745695114136
# Epoch 157/200, Loss: 0.9316707849502563
# Epoch 158/200, Loss: 0.5660902857780457
# Epoch 159/200, Loss: 0.20449073612689972
# Epoch 160/200, Loss: 0.5789368748664856
# Epoch 161/200, Loss: 0.9003012776374817
# Epoch 162/200, Loss: 0.2815638482570648
# Epoch 163/200, Loss: 0.3024170994758606
# Epoch 164/200, Loss: 0.49319925904273987
# Epoch 165/200, Loss: 0.45705652236938477
# Epoch 166/200, Loss: 0.21955016255378723
# Epoch 167/200, Loss: 0.6178079843521118
# Epoch 168/200, Loss: 1.430873155593872
# Epoch 169/200, Loss: 0.5577335953712463
# Epoch 170/200, Loss: 0.820067286491394
# Epoch 171/200, Loss: 0.6089008450508118
# Epoch 172/200, Loss: 0.46415606141090393
# Epoch 173/200, Loss: 0.5955420136451721
# Epoch 174/200, Loss: 0.39863601326942444
# Epoch 175/200, Loss: 0.6591588854789734
# Epoch 176/200, Loss: 0.8360414505004883
# Epoch 177/200, Loss: 0.21672067046165466
# Epoch 178/200, Loss: 0.4953276216983795
# Epoch 179/200, Loss: 0.1260823905467987
# Epoch 180/200, Loss: 0.4574894905090332
# Epoch 181/200, Loss: 0.35547682642936707
# Epoch 182/200, Loss: 0.8905299305915833
# Epoch 183/200, Loss: 0.1024743914604187
# Epoch 184/200, Loss: 0.278102844953537
# Epoch 185/200, Loss: 0.43544816970825195
# Epoch 186/200, Loss: 0.6329594850540161
# Epoch 187/200, Loss: 0.12175609171390533
# Epoch 188/200, Loss: 0.1426459699869156
# Epoch 189/200, Loss: 0.4587121605873108
# Epoch 190/200, Loss: 0.13080061972141266
# Epoch 191/200, Loss: 0.5660299062728882
# Epoch 192/200, Loss: 0.19992728531360626
# Epoch 193/200, Loss: 0.6521115899085999
# Epoch 194/200, Loss: 0.23195083439350128
# Epoch 195/200, Loss: 0.6542304754257202
# Epoch 196/200, Loss: 0.18787768483161926
# Epoch 197/200, Loss: 0.34851449728012085
# Epoch 198/200, Loss: 0.14001932740211487
# Epoch 199/200, Loss: 0.030536983162164688
# Epoch 200/200, Loss: 0.8095002174377441

# %%
# Evaluate the model on the validation set
model.eval()
correct_predictions = 0
total_predictions = 0

with torch.no_grad():
    for inputs, labels in val_dataloader:
        # Mueve los datos de entrada y las etiquetas al dispositivo
        inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = model(inputs)
        predicted = outputs.argmax(dim=1)
        actual = labels.argmax(dim=1)
        correct_predictions += (predicted == actual).sum().item()
        total_predictions += labels.size(0)

accuracy = correct_predictions / total_predictions
print(f'Validation Accuracy: {accuracy:.4f}')
# Out:
# Validation Accuracy: 0.0921

# %%
import time

# Evaluate the model on the validation set
model.eval()
correct_predictions = 0
total_predictions = 0

with torch.no_grad():
    for inputs, labels in val_dataloader:
        # Mueve los datos de entrada y las etiquetas al dispositivo
        inputs, labels = inputs.to(device), labels.to(device)
        
        outputs = model(inputs)
        predicted = outputs.argmax(dim=1)
        actual = labels.argmax(dim=1)

        # Display results
        for i in range(len(inputs)):
            input_sentence = " ".join([index_to_word[idx.item()] for idx in inputs[i] if idx.item() != 0])
            predicted_word = index_to_word[predicted[i].item()]
            actual_word = index_to_word[actual[i].item()]
            correct = predicted[i].item() == actual[i].item()
            print(f"Sentence: {input_sentence}")
            print(f"Predicted: {predicted_word}")
            print(f"Actual: {actual_word}")
            print(f"Correct: {correct}")
            print()

            if correct:
                correct_predictions += 1
            total_predictions += 1

            time.sleep(3)  # Wait for 1 second between predictions

accuracy = correct_predictions / total_predictions
print(f'Validation Accuracy: {accuracy:.4f}')
# Out:
# Sentence: me to bring him
# Predicted: and
# Actual: out
# Correct: False
#
# Sentence: this account of you we
# Predicted: are
# Actual: have
# Correct: False
#
# Sentence: is all that district and there were
# Predicted: six
# Actual: marks
# Correct: False
#
# Sentence: no
# Predicted: i
# Actual: great
# Correct: False
#
# Sentence: peterson
# Predicted: the
# Actual: run
# Correct: False
#
# Sentence: for
# Predicted: the
# Actual: three
# Correct: False
#
# Sentence: grounds a stableboy
# Predicted: acquaintance
# Actual: had
# Correct: False
#
# Sentence: sherlock holmes looked deeply chagrined he drew
# Predicted: out
# Actual: a
# Correct: False
#
# Sentence: our friends premises
# Predicted: by
# Actual: and
# Correct: False
#
# Sentence: it as the front of a
# Predicted: man
# Actual: picture
# Correct: False
#
# Sentence: the garden behind into the stable lane so
# Predicted: that
# Actual: long
# Correct: False
#
# Sentence: that it helps us much i think myself that it is
# Predicted: not
# Actual: a
# Correct: False
#
# Sentence: as a trivial example of
# Predicted: his
# Actual: observation
# Correct: False
#
# Sentence: his own save
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: explain afterwards i hadnt been
# Predicted: for
# Actual: at
# Correct: False
#
# Sentence: blood by direct descent and
# Predicted: he
# Actual: tudor
# Correct: False
#
# Sentence: if you can call upon me at
# Predicted: all
# Actual: my
# Correct: False
#
# Sentence: his wont my thoughts rather than my words if i
# Predicted: may
# Actual: claim
# Correct: False
#
# Sentence: into a small bedroom which looked out upon the back
# Predicted: and
# Actual: of
# Correct: False
#
# Sentence: gamekeeper lost sight of them
# Predicted: all
# Actual: the
# Correct: False
#
# Sentence: you will see me when
# Predicted: your
# Actual: all
# Correct: False
#
# Sentence: three gems had been torn
# Predicted: and
# Actual: away
# Correct: False
#
# Sentence: it
# Predicted: was
# Actual: is
# Correct: False
#
# Sentence: done about the same
# Predicted: as
# Actual: time
# Correct: False
#
# Sentence: shuddered to think
# Predicted: that
# Actual: of
# Correct: False
#
# Sentence: complete you had heard ryder of this blue stone of the countess
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: take place and many a little problem
# Predicted: i
# Actual: will
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: cannot
# Correct: False
#
# Sentence: together mccarthy had one son a lad of eighteen and
# Predicted: taken
# Actual: turner
# Correct: False
#
# Sentence: clair which lay uncovered as the tide receded
# Predicted: receded
# Actual: and
# Correct: False
#
# Sentence: that will do said holmes
# Predicted: laying
# Actual: as
# Correct: False
#
# Sentence: was running hard with occasional little springs such as a
# Predicted: man
# Actual: weary
# Correct: False
#
# Sentence: her instinct is at once to rush to the thing
# Predicted: here
# Actual: which
# Correct: False
#
# Sentence: less than fortyfive from their
# Predicted: have
# Actual: conversation
# Correct: False
#
# Sentence: man who was nearly fifteen
# Predicted: in
# Actual: years
# Correct: False
#
# Sentence: there had been a struggle and finally where a few drops
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: is of course obvious upon the face of it and
# Predicted: so
# Actual: also
# Correct: False
#
# Sentence: in scotland one week and be raising money to build an
# Predicted: entirely
# Actual: orphanage
# Correct: False
#
# Sentence: about the garden with a revolver in
# Predicted: a
# Actual: his
# Correct: False
#
# Sentence: as a rule said holmes the
# Predicted: shoulders
# Actual: more
# Correct: False
#
# Sentence: dread of losing a
# Predicted: could
# Actual: client
# Correct: False
#
# Sentence: seen i had been lying in an angle of the
# Predicted: it
# Actual: hedge
# Correct: False
#
# Sentence: which i was eager enough to do for my curiosity and
# Predicted: what
# Actual: sympathy
# Correct: False
#
# Sentence: turned
# Predicted: down
# Actual: and
# Correct: False
#
# Sentence: it was with his barmaid wife that he had spent the last three days
# Predicted: here
# Actual: in
# Correct: False
#
# Sentence: column of the morning post and dates as you see some
# Predicted: friend
# Actual: weeks
# Correct: False
#
# Sentence: proceed to business then said
# Predicted: he
# Actual: he
# Correct: True
#
# Sentence: brown
# Predicted: gaiters
# Actual: a
# Correct: False
#
# Sentence: capable performer but a composer
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: then that will simplify matters we descended and started off
# Predicted: the
# Actual: once
# Correct: False
#
# Sentence: has always
# Predicted: a
# Actual: fallen
# Correct: False
#
# Sentence: i think that i mentioned to you that the doctor kept a cheetah and
# Predicted: from
# Actual: a
# Correct: False
#
# Sentence: and so do i it is precisely for that reason that we
# Predicted: are
# Actual: are
# Correct: True
#
# Sentence: thicksoled shootingboots and a grey
# Predicted: right
# Actual: cloak
# Correct: False
#
# Sentence: will allow is not an action
# Predicted: to
# Actual: likely
# Correct: False
#
# Sentence: letter
# Predicted: the
# Actual: k
# Correct: False
#
# Sentence: carry my stone to kilburn there was a little shed in
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: murdertrap on the whole riverside and i
# Predicted: was
# Actual: fear
# Correct: False
#
# Sentence: who had at first been overjoyed to
# Predicted: the
# Actual: see
# Correct: False
#
# Sentence: sold to mr windigate of the alpha at
# Predicted: the
# Actual: 12s
# Correct: False
#
# Sentence: me
# Predicted: to
# Actual: in
# Correct: False
#
# Sentence: although i am a man whose character has never yet
# Predicted: long
# Actual: borne
# Correct: False
#
# Sentence: her imprudence in allowing this brute to trace
# Predicted: and
# Actual: her
# Correct: False
#
# Sentence: prepare for the new role i have
# Predicted: heard
# Actual: to
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: reached
# Correct: False
#
# Sentence: the way
# Predicted: to
# Actual: and
# Correct: False
#
# Sentence: yes sir he told me that a gipsy had done
# Predicted: back
# Actual: it
# Correct: False
#
# Sentence: is
# Predicted: a
# Actual: a
# Correct: True
#
# Sentence: my name said he is john openshaw but my own affairs
# Predicted: was
# Actual: have
# Correct: False
#
# Sentence: both to her husband and to
# Predicted: make
# Actual: her
# Correct: False
#
# Sentence: then i shall call upon you in a day or in
# Predicted: the
# Actual: two
# Correct: False
#
# Sentence: reward you this ring he slipped
# Predicted: his
# Actual: an
# Correct: False
#
# Sentence: enough
# Predicted: but
# Actual: to
# Correct: False
#
# Sentence: when just as i came to the altar rails i glanced back and saw
# Predicted: that
# Actual: frank
# Correct: False
#
# Sentence: was that
# Predicted: he
# Actual: she
# Correct: False
#
# Sentence: such a day and at such an hour
# Predicted: or
# Actual: but
# Correct: False
#
# Sentence: bet is off that
# Predicted: it
# Actual: is
# Correct: False
#
# Sentence: i have been too busy to think of food and i am likely to be
# Predicted: a
# Actual: busier
# Correct: False
#
# Sentence: i have seen those symptoms before
# Predicted: which
# Actual: said
# Correct: False
#
# Sentence: disappointment i have no doubt that i am myself
# Predicted: mr
# Actual: to
# Correct: False
#
# Sentence: would carry me to this man
# Predicted: with
# Actual: breckinridge
# Correct: False
#
# Sentence: a man had waited outside the window someone
# Predicted: had
# Actual: had
# Correct: True
#
# Sentence: at once not only
# Predicted: now
# Actual: of
# Correct: False
#
# Sentence: knots that and a toothbrush are i think all that we
# Predicted: shall
# Actual: need
# Correct: False
#
# Sentence: and
# Predicted: i
# Actual: has
# Correct: False
#
# Sentence: discretion whom i may trust with a matter of
# Predicted: depend
# Actual: the
# Correct: False
#
# Sentence: than that which was associated
# Predicted: in
# Actual: with
# Correct: False
#
# Sentence: come
# Predicted: at
# Actual: with
# Correct: False
#
# Sentence: the corners of his nostrils
# Predicted: tinged
# Actual: were
# Correct: False
#
# Sentence: were planning for i would have told you that
# Predicted: i
# Actual: your
# Correct: False
#
# Sentence: to his chamber and was down
# Predicted: into
# Actual: again
# Correct: False
#
# Sentence: the fashion of old countryhouses
# Predicted: which
# Actual: a
# Correct: False
#
# Sentence: do he went off to france upon the business
# Predicted: but
# Actual: of
# Correct: False
#
# Sentence: it was naturally my
# Predicted: life
# Actual: intention
# Correct: False
#
# Sentence: of complaint can set it
# Predicted: for
# Actual: going
# Correct: False
#
# Sentence: pshaw they did not
# Predicted: come
# Actual: know
# Correct: False
#
# Sentence: husband you found so
# Predicted: as
# Actual: easy
# Correct: False
#
# Sentence: for the observerexcellent for drawing
# Predicted: it
# Actual: the
# Correct: False
#
# Sentence: the snake is writhing
# Predicted: i
# Actual: towards
# Correct: False
#
# Sentence: sherlock
# Predicted: holmes
# Actual: holmes
# Correct: True
#
# Sentence: so
# Predicted: i
# Actual: i
# Correct: True
#
# Sentence: he entered to say so but he plunged
# Predicted: when
# Actual: at
# Correct: False
#
# Sentence: matter of fowls and i have a fiver on it that the
# Predicted: very
# Actual: bird
# Correct: False
#
# Sentence: face and became
# Predicted: a
# Actual: a
# Correct: True
#
# Sentence: precisely you allude to my
# Predicted: own
# Actual: attempt
# Correct: False
#
# Sentence: tropics a series of disgraceful brawls took place two
# Predicted: which
# Actual: of
# Correct: False
#
# Sentence: as he spoke there was a tap at
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: above as i
# Predicted: waited
# Actual: stood
# Correct: False
#
# Sentence: this mysterious assistant and
# Predicted: that
# Actual: found
# Correct: False
#
# Sentence: his pipe and leaning back in his
# Predicted: chair
# Actual: chair
# Correct: True
#
# Sentence: when she
# Predicted: met
# Actual: reached
# Correct: False
#
# Sentence: morning he was
# Predicted: a
# Actual: saying
# Correct: False
#
# Sentence: we were
# Predicted: seated
# Actual: as
# Correct: False
#
# Sentence: between us
# Predicted: but
# Actual: that
# Correct: False
#
# Sentence: in london and took us to live
# Predicted: the
# Actual: with
# Correct: False
#
# Sentence: have been senseless for a long time when i came to i found that
# Predicted: i
# Actual: it
# Correct: False
#
# Sentence: by the same brilliant reasoning
# Predicted: and
# Actual: every
# Correct: False
#
# Sentence: it said a gentleman who desires to consult
# Predicted: such
# Actual: you
# Correct: False
#
# Sentence: peculiarthat is the very word said
# Predicted: holmes
# Actual: holmes
# Correct: True
#
# Sentence: but a cripple said i what could he have
# Predicted: been
# Actual: done
# Correct: False
#
# Sentence: as the burning poison waxed or waned
# Predicted: the
# Actual: in
# Correct: False
#
# Sentence: you are the first who have ever heard my story my
# Predicted: wife
# Actual: father
# Correct: False
#
# Sentence: up we
# Predicted: shall
# Actual: found
# Correct: False
#
# Sentence: at me her
# Predicted: and
# Actual: eyes
# Correct: False
#
# Sentence: acute that i could not
# Predicted: help
# Actual: only
# Correct: False
#
# Sentence: with making away with mr neville stoh
# Predicted: was
# Actual: come
# Correct: False
#
# Sentence: brass box stood open and empty beside it as i glanced
# Predicted: up
# Actual: at
# Correct: False
#
# Sentence: there will call upon you tonight at
# Predicted: you
# Actual: a
# Correct: False
#
# Sentence: goodevening mr james windibank said holmes
# Predicted: as
# Actual: i
# Correct: False
#
# Sentence: send him away to his death he sprang from
# Predicted: it
# Actual: his
# Correct: False
#
# Sentence: there was
# Predicted: a
# Actual: a
# Correct: True
#
# Sentence: up we found the brass
# Predicted: so
# Actual: box
# Correct: False
#
# Sentence: description i eliminated everything from it which could be
# Predicted: any
# Actual: the
# Correct: False
#
# Sentence: bradshaw it
# Predicted: was
# Actual: is
# Correct: False
#
# Sentence: bristol and his father did not
# Predicted: mine
# Actual: know
# Correct: False
#
# Sentence: give me your coat and umbrella said holmes they
# Predicted: are
# Actual: may
# Correct: False
#
# Sentence: lay back in the cab
# Predicted: the
# Actual: humming
# Correct: False
#
# Sentence: him get out and walk rapidly out of the yard though i
# Predicted: would
# Actual: was
# Correct: False
#
# Sentence: will you come with me asked holmes glancing
# Predicted: at
# Actual: up
# Correct: False
#
# Sentence: a very
# Predicted: serious
# Actual: serious
# Correct: True
#
# Sentence: then let us do so watson i fear that you will find it
# Predicted: line
# Actual: very
# Correct: False
#
# Sentence: still if i had married lord st simon of course id
# Predicted: have
# Actual: have
# Correct: True
#
# Sentence: not be bought under half a
# Predicted: half
# Actual: crown
# Correct: False
#
# Sentence: old trick of stepping in
# Predicted: the
# Actual: at
# Correct: False
#
# Sentence: horsham i doubt
# Predicted: that
# Actual: if
# Correct: False
#
# Sentence: mission you
# Predicted: see
# Actual: see
# Correct: True
#
# Sentence: in london and took us to live with
# Predicted: the
# Actual: him
# Correct: False
#
# Sentence: behind and yet was upon the left side now how can that
# Predicted: he
# Actual: be
# Correct: False
#
# Sentence: yes sir he told me that a gipsy had done it
# Predicted: was
# Actual: for
# Correct: False
#
# Sentence: morning he was saying to me that whatever happened i was to
# Predicted: do
# Actual: be
# Correct: False
#
# Sentence: led up to it
# Predicted: most
# Actual: but
# Correct: False
#
# Sentence: no furniture save a little pallet
# Predicted: a
# Actual: bed
# Correct: False
#
# Sentence: convinced that something was amiss
# Predicted: to
# Actual: with
# Correct: False
#
# Sentence: aristocratic club and there having charming manners he
# Predicted: come
# Actual: was
# Correct: False
#
# Sentence: he seemed
# Predicted: to
# Actual: to
# Correct: True
#
# Sentence: just as it happened sir said he
# Predicted: and
# Actual: when
# Correct: False
#
# Sentence: yours i should be exceedingly glad to have a little talk
# Predicted: to
# Actual: with
# Correct: False
#
# Sentence: simon is
# Predicted: it
# Actual: a
# Correct: False
#
# Sentence: senders
# Predicted: been
# Actual: to
# Correct: False
#
# Sentence: to eyford in berkshire it is
# Predicted: no
# Actual: a
# Correct: False
#
# Sentence: the london press has not had very full accounts i have just
# Predicted: sir
# Actual: been
# Correct: False
#
# Sentence: any bearing upon the case but i beg that you
# Predicted: had
# Actual: will
# Correct: False
#
# Sentence: settle this little matter of
# Predicted: your
# Actual: yours
# Correct: False
#
# Sentence: implies as you
# Predicted: understand
# Actual: will
# Correct: False
#
# Sentence: i have
# Predicted: seen
# Actual: already
# Correct: False
#
# Sentence: i bent over her she suddenly shrieked out in a voice which i
# Predicted: had
# Actual: shall
# Correct: False
#
# Sentence: boots i think watson that you are now standing in
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: became suspicious i found it hard to think evil
# Predicted: however
# Actual: of
# Correct: False
#
# Sentence: the london press has not had very
# Predicted: much
# Actual: full
# Correct: False
#
# Sentence: itself upon
# Predicted: the
# Actual: me
# Correct: False
#
# Sentence: i do
# Predicted: not
# Actual: not
# Correct: True
#
# Sentence: missing it said on the morning of the fourteenth
# Predicted: as
# Actual: a
# Correct: False
#
# Sentence: north south east and west every man who had a
# Predicted: strange
# Actual: shade
# Correct: False
#
# Sentence: there is a strong presumption that the person
# Predicted: was
# Actual: whom
# Correct: False
#
# Sentence: no his friend he wished us to leave him alone
# Predicted: at
# Actual: he
# Correct: False
#
# Sentence: he may have
# Predicted: to
# Actual: been
# Correct: False
#
# Sentence: my share of that it was more a feeling of dutya feeling that
# Predicted: a
# Actual: some
# Correct: False
#
# Sentence: that this will prove to be
# Predicted: other
# Actual: our
# Correct: False
#
# Sentence: held a candle
# Predicted: upon
# Actual: in
# Correct: False
#
# Sentence: the fire you see mr holmes said he my
# Predicted: companion
# Actual: wife
# Correct: False
#
# Sentence: afternoon we rattled through an
# Predicted: instant
# Actual: endless
# Correct: False
#
# Sentence: out
# Predicted: at
# Actual: like
# Correct: False
#
# Sentence: his whole appearance he carried a broadbrimmed hat in
# Predicted: the
# Actual: his
# Correct: False
#
# Sentence: tell me dad said she looking i
# Predicted: could
# Actual: thought
# Correct: False
#
# Sentence: down into holborn holmes pushed open the
# Predicted: window
# Actual: door
# Correct: False
#
# Sentence: well i dont know
# Predicted: why
# Actual: why
# Correct: True
#
# Sentence: one day
# Predicted: a
# Actual: father
# Correct: False
#
# Sentence: lodge
# Predicted: your
# Actual: in
# Correct: False
#
# Sentence: room while you explain
# Predicted: if
# Actual: this
# Correct: False
#
# Sentence: the blind that was a week ago and from that time i have not
# Predicted: such
# Actual: sat
# Correct: False
#
# Sentence: i saw an illdressed vagabond in
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: the two mccarthys were seen after the
# Predicted: house
# Actual: time
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: had
# Correct: False
#
# Sentence: had there
# Predicted: was
# Actual: been
# Correct: False
#
# Sentence: connivance and assistance of his wife he disguised
# Predicted: the
# Actual: himself
# Correct: False
#
# Sentence: in breaking the window and by the approach
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: the harvest
# Predicted: you
# Actual: which
# Correct: False
#
# Sentence: a fierce old
# Predicted: friend
# Actual: bird
# Correct: False
#
# Sentence: well then youve lost
# Predicted: a
# Actual: your
# Correct: False
#
# Sentence: you can understand said holmes suavely
# Predicted: there
# Actual: that
# Correct: False
#
# Sentence: be some 30000 and for you jones it
# Predicted: is
# Actual: will
# Correct: False
#
# Sentence: five
# Predicted: and
# Actual: dried
# Correct: False
#
# Sentence: it said do come i
# Predicted: am
# Actual: am
# Correct: True
#
# Sentence: hatherley
# Predicted: said
# Actual: was
# Correct: False
#
# Sentence: who are sound in body
# Predicted: they
# Actual: and
# Correct: False
#
# Sentence: a revolver but holmes hunting crop came down on the
# Predicted: left
# Actual: mans
# Correct: False
#
# Sentence: appeared with
# Predicted: a
# Actual: a
# Correct: True
#
# Sentence: address which can only
# Predicted: some
# Actual: mean
# Correct: False
#
# Sentence: always instructive but if you have followed recent events
# Predicted: you
# Actual: so
# Correct: False
#
# Sentence: windibank did not wish us
# Predicted: out
# Actual: to
# Correct: False
#
# Sentence: the other ones
# Predicted: still
# Actual: both
# Correct: False
#
# Sentence: little breakfast with him do you feel equal
# Predicted: to
# Actual: to
# Correct: True
#
# Sentence: early days of my association with holmes when we were sharing
# Predicted: they
# Actual: rooms
# Correct: False
#
# Sentence: palm of my hand i rushed forward fell down
# Predicted: the
# Actual: clapped
# Correct: False
#
# Sentence: ah yes i should like a few particulars as to this
# Predicted: when
# Actual: young
# Correct: False
#
# Sentence: sign
# Predicted: that
# Actual: of
# Correct: False
#
# Sentence: boy to apologise to him for the
# Predicted: window
# Actual: wrong
# Correct: False
#
# Sentence: and not sink he has
# Predicted: seen
# Actual: little
# Correct: False
#
# Sentence: misfortune impressed me my sister and
# Predicted: you
# Actual: i
# Correct: False
#
# Sentence: the doormat in that way i didnt know much of
# Predicted: that
# Actual: what
# Correct: False
#
# Sentence: moment her knees seemed to
# Predicted: me
# Actual: give
# Correct: False
#
# Sentence: certainly sir said baker who had risen and tucked his
# Predicted: chair
# Actual: newly
# Correct: False
#
# Sentence: her instinct is at once to
# Predicted: the
# Actual: rush
# Correct: False
#
# Sentence: anything but it never really became bad for her until
# Predicted: we
# Actual: after
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: think
# Correct: False
#
# Sentence: advise
# Predicted: you
# Actual: her
# Correct: False
#
# Sentence: the fugitives
# Predicted: and
# Actual: disappeared
# Correct: False
#
# Sentence: we must sit without light he would see
# Predicted: the
# Actual: it
# Correct: False
#
# Sentence: yes sir that
# Predicted: be
# Actual: is
# Correct: False
#
# Sentence: i waited until midnight but there was
# Predicted: no
# Actual: no
# Correct: True
#
# Sentence: disposal and i was quickly between the sheets for
# Predicted: i
# Actual: i
# Correct: True
#
# Sentence: adopted her and
# Predicted: perhaps
# Actual: have
# Correct: False
#
# Sentence: i believe
# Predicted: he
# Actual: mr
# Correct: False
#
# Sentence: they found in the
# Predicted: address
# Actual: pockets
# Correct: False
#
# Sentence: for i am
# Predicted: in
# Actual: a
# Correct: False
#
# Sentence: use the official police as well would you give me
# Predicted: a
# Actual: an
# Correct: False
#
# Sentence: bright
# Predicted: morning
# Actual: crisp
# Correct: False
#
# Sentence: advice looks upon all that i tell him about it as
# Predicted: to
# Actual: the
# Correct: False
#
# Sentence: you were yourself struck by the nature of
# Predicted: a
# Actual: the
# Correct: False
#
# Sentence: that this was
# Predicted: the
# Actual: where
# Correct: False
#
# Sentence: holmes sat in his big
# Predicted: when
# Actual: armchair
# Correct: False
#
# Sentence: yes jem there were two barredtailed ones and i
# Predicted: have
# Actual: could
# Correct: False
#
# Sentence: obtaining a note as the dropping
# Predicted: is
# Actual: of
# Correct: False
#
# Sentence: which looked keenly about it and then with a
# Predicted: start
# Actual: hand
# Correct: False
#
# Sentence: examine minutely the cracks
# Predicted: the
# Actual: between
# Correct: False
#
# Sentence: lapse of two years
# Predicted: has
# Actual: has
# Correct: True
#
# Sentence: was his aversion to the negroes and his dislike of the
# Predicted: cold
# Actual: republican
# Correct: False
#
# Sentence: she died just two years ago and it is of her death that i wish
# Predicted: you
# Actual: to
# Correct: False
#
# Sentence: it behind him like a
# Predicted: cold
# Actual: man
# Correct: False
#
# Sentence: index in andover in 77 and there was something
# Predicted: sort
# Actual: of
# Correct: False
#
# Sentence: tell me broke in the engineer is
# Predicted: the
# Actual: dr
# Correct: False
#
# Sentence: gently
# Predicted: waving
# Actual: smiling
# Correct: False
#
# Sentence: yesterday morning the blow fell in the very shape
# Predicted: which
# Actual: in
# Correct: False
#
# Sentence: pray continue said holmes your narrative promises to be
# Predicted: most
# Actual: a
# Correct: False
#
# Sentence: i waited until midnight but there was no sign of his
# Predicted: father
# Actual: return
# Correct: False
#
# Sentence: our friends premises and
# Predicted: waited
# Actual: felt
# Correct: False
#
# Sentence: companions but i
# Predicted: am
# Actual: could
# Correct: False
#
# Sentence: yourself that
# Predicted: i
# Actual: the
# Correct: False
#
# Sentence: but there was no great difficulty in the first
# Predicted: that
# Actual: stage
# Correct: False
#
# Sentence: he didnt mind
# Predicted: and
# Actual: me
# Correct: False
#
# Sentence: was much
# Predicted: for
# Actual: more
# Correct: False
#
# Sentence: the
# Predicted: coroner
# Actual: turf
# Correct: False
#
# Sentence: jewelcase the evidence against him was so strong that
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: from all gossip upon the matter
# Predicted: the
# Actual: but
# Correct: False
#
# Sentence: 88 10s while he has 220
# Predicted: to
# Actual: standing
# Correct: False
#
# Sentence: of fact
# Predicted: who
# Actual: seven
# Correct: False
#
# Sentence: dress i knew that it was a rich material she
# Predicted: was
# Actual: spoke
# Correct: False
#
# Sentence: was very weak but i have had a good deal
# Predicted: before
# Actual: to
# Correct: False
#
# Sentence: it is very good of lord st simon to honour my head by putting
# Predicted: on
# Actual: it
# Correct: False
#
# Sentence: you have
# Predicted: a
# Actual: done
# Correct: False
#
# Sentence: sherlock holmes standing fully dressed by
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: the meaning of this extraordinary performance could possibly be
# Predicted: reached
# Actual: they
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: should
# Correct: False
#
# Sentence: of 85 on the fourth day
# Predicted: said
# Actual: after
# Correct: False
#
# Sentence: yes my stepfather
# Predicted: has
# Actual: i
# Correct: False
#
# Sentence: foreign tongue in a tone as
# Predicted: long
# Actual: though
# Correct: False
#
# Sentence: oh yes in a hundred other ways he has helped him
# Predicted: in
# Actual: everybody
# Correct: False
#
# Sentence: that was it
# Predicted: said
# Actual: sir
# Correct: False
#
# Sentence: of his friend sir george burnwell
# Predicted: he
# Actual: was
# Correct: False
#
# Sentence: and inconsequential narrative but
# Predicted: was
# Actual: on
# Correct: False
#
# Sentence: roll from his pocket it
# Predicted: is
# Actual: is
# Correct: True
#
# Sentence: she
# Predicted: will
# Actual: brought
# Correct: False
#
# Sentence: i have been a governess for five years said she in the
# Predicted: world
# Actual: family
# Correct: False
#
# Sentence: have the great kindness to recommence your
# Predicted: right
# Actual: narrative
# Correct: False
#
# Sentence: to be back before three
# Predicted: oclock
# Actual: i
# Correct: False
#
# Sentence: of the most resolute of
# Predicted: the
# Actual: men
# Correct: False
#
# Sentence: i could hardly believe
# Predicted: that
# Actual: my
# Correct: False
#
# Sentence: time now keep your
# Predicted: statement
# Actual: eyes
# Correct: False
#
# Sentence: what
# Predicted: is
# Actual: then
# Correct: False
#
# Sentence: this aroused my curiosity so when i went
# Predicted: down
# Actual: out
# Correct: False
#
# Sentence: when
# Predicted: he
# Actual: holmes
# Correct: False
#
# Sentence: in the dress is a
# Predicted: little
# Actual: pocket
# Correct: False
#
# Sentence: he would not speak about it to the coroner was because i
# Predicted: should
# Actual: was
# Correct: False
#
# Sentence: slowly jerkily but as none knew better than myself
# Predicted: in
# Actual: with
# Correct: False
#
# Sentence: slept
# Predicted: until
# Actual: badly
# Correct: False
#
# Sentence: oh no no i want the doctors
# Predicted: and
# Actual: advice
# Correct: False
#
# Sentence: announced in the papers of yesterday occurred
# Predicted: which
# Actual: on
# Correct: False
#
# Sentence: here
# Predicted: is
# Actual: in
# Correct: False
#
# Sentence: well he is sure to keep an eye on the papers
# Predicted: and
# Actual: since
# Correct: False
#
# Sentence: should not be
# Predicted: able
# Actual: traced
# Correct: False
#
# Sentence: by whom he now has two children he had
# Predicted: been
# Actual: no
# Correct: False
#
# Sentence: my judgment the fourth smartest
# Predicted: in
# Actual: man
# Correct: False
#
# Sentence: capital by
# Predicted: the
# Actual: which
# Correct: False
#
# Sentence: are but that is a mere detail i have taken you fully into
# Predicted: my
# Actual: my
# Correct: True
#
# Sentence: is not the gritty grey dust
# Predicted: upon
# Actual: of
# Correct: False
#
# Sentence: considering the formidable letters which were received
# Predicted: himself
# Actual: by
# Correct: False
#
# Sentence: endless succession of sombre
# Predicted: which
# Actual: and
# Correct: False
#
# Sentence: thing but exceedingly hotheaded and devotedly attached to me
# Predicted: and
# Actual: she
# Correct: False
#
# Sentence: find did she know where
# Predicted: to
# Actual: her
# Correct: False
#
# Sentence: second is that the murdered man was
# Predicted: even
# Actual: heard
# Correct: False
#
# Sentence: miss hunter for falling in with our whims so far as to cut
# Predicted: it
# Actual: your
# Correct: False
#
# Sentence: i will
# Predicted: do
# Actual: make
# Correct: False
#
# Sentence: he cant lie in the street may we bring him
# Predicted: and
# Actual: in
# Correct: False
#
# Sentence: rucastle suddenly remarked that it was time
# Predicted: that
# Actual: to
# Correct: False
#
# Sentence: seven miles from
# Predicted: reading
# Actual: eyford
# Correct: False
#
# Sentence: now do try to come and i shall meet you
# Predicted: a
# Actual: with
# Correct: False
#
# Sentence: on it he wanted her to sign a paper so that whether she married
# Predicted: her
# Actual: or
# Correct: False
#
# Sentence: stillness the door of my room swung slowly open the woman
# Predicted: across
# Actual: was
# Correct: False
#
# Sentence: wire here we may take it
# Predicted: and
# Actual: that
# Correct: False
#
# Sentence: and also with the result of
# Predicted: driving
# Actual: causing
# Correct: False
#
# Sentence: name is hugh boone and his hideous face is one which
# Predicted: looked
# Actual: is
# Correct: False
#
# Sentence: when i found myself
# Predicted: through
# Actual: in
# Correct: False
#
# Sentence: the price of the gold chasing is incalculable the
# Predicted: most
# Actual: lowest
# Correct: False
#
# Sentence: my
# Predicted: dear
# Actual: experience
# Correct: False
#
# Sentence: four
# Predicted: i
# Actual: and
# Correct: False
#
# Sentence: for me tomorrow about eleven give her
# Predicted: position
# Actual: her
# Correct: False
#
# Sentence: pray continue said holmes your
# Predicted: stepfather
# Actual: narrative
# Correct: False
#
# Sentence: little problem promises to be the most interesting which
# Predicted: i
# Actual: has
# Correct: False
#
# Sentence: which i beg that you will give
# Predicted: me
# Actual: a
# Correct: False
#
# Sentence: oh
# Predicted: yes
# Actual: anstruther
# Correct: False
#
# Sentence: your way merely in order that
# Predicted: night
# Actual: you
# Correct: False
#
# Sentence: behind him to me who
# Predicted: was
# Actual: knew
# Correct: False
#
# Sentence: advertised and i answered advertisements but
# Predicted: i
# Actual: without
# Correct: False
#
# Sentence: took hosmermr angelwas a cashier in an office in
# Predicted: the
# Actual: leadenhall
# Correct: False
#
# Sentence: oh to the other side of the west end it may
# Predicted: never
# Actual: be
# Correct: False
#
# Sentence: had there been women in the house i should
# Predicted: like
# Actual: have
# Correct: False
#
# Sentence: precisely and if it were guilty why did he not invent a lie
# Predicted: for
# Actual: his
# Correct: False
#
# Sentence: i thank you said the young man
# Predicted: come
# Actual: rising
# Correct: False
#
# Sentence: heavy like those of a man who is weighed down with some
# Predicted: of
# Actual: great
# Correct: False
#
# Sentence: hum said holmes sinking back in deep thought he is
# Predicted: alone
# Actual: still
# Correct: False
#
# Sentence: westaways
# Predicted: to
# Actual: and
# Correct: False
#
# Sentence: i assure you watson without affectation
# Predicted: my
# Actual: that
# Correct: False
#
# Sentence: he came down into the office just this day eight weeks with
# Predicted: him
# Actual: this
# Correct: False
#
# Sentence: sudden turn to rain with high autumnal winds
# Predicted: the
# Actual: and
# Correct: False
#
# Sentence: could not have carried out two deaths in such a way as to
# Predicted: that
# Actual: deceive
# Correct: False
#
# Sentence: insanely in love with her but some two years ago when he
# Predicted: rose
# Actual: was
# Correct: False
#
# Sentence: whose graceful
# Predicted: is
# Actual: figure
# Correct: False
#
# Sentence: this man boone had thrust
# Predicted: forward
# Actual: neville
# Correct: False
#
# Sentence: kindly put your army revolver
# Predicted: and
# Actual: in
# Correct: False
#
# Sentence: a builder
# Predicted: orange
# Actual: must
# Correct: False
#
# Sentence: the
# Predicted: coroner
# Actual: reaction
# Correct: False
#
# Sentence: remarkable as being the scene of the
# Predicted: death
# Actual: death
# Correct: True
#
# Sentence: that you wont speak to me for fifty minutes he curled himself
# Predicted: and
# Actual: up
# Correct: False
#
# Sentence: against a man in the
# Predicted: parish
# Actual: prime
# Correct: False
#
# Sentence: large masses of nickel and of tin were discovered stored
# Predicted: by
# Actual: in
# Correct: False
#
# Sentence: were new raised
# Predicted: to
# Actual: from
# Correct: False
#
# Sentence: until i come back well we talked it over and he had fixed
# Predicted: a
# Actual: it
# Correct: False
#
# Sentence: take place and many a little problem will be presented
# Predicted: to
# Actual: which
# Correct: False
#
# Sentence: blonde woman stood in the opening
# Predicted: manner
# Actual: clad
# Correct: False
#
# Sentence: oh yes he is the greengrocer
# Predicted: side
# Actual: who
# Correct: False
#
# Sentence: strength together we rushed into the room it
# Predicted: was
# Actual: was
# Correct: True
#
# Sentence: but he is right oh i know
# Predicted: that
# Actual: that
# Correct: True
#
# Sentence: the glass still keeps very high he remarked as he sat down
# Predicted: with
# Actual: it
# Correct: False
#
# Sentence: sherlock holmes sprang out of his chair as if he had
# Predicted: passed
# Actual: been
# Correct: False
#
# Sentence: flamecoloured silk and secured at the neck with a brooch
# Predicted: he
# Actual: which
# Correct: False
#
# Sentence: the note into
# Predicted: the
# Actual: my
# Correct: False
#
# Sentence: sewn upon it and a fringe of little
# Predicted: fingers
# Actual: black
# Correct: False
#
# Sentence: do you receive much company he
# Predicted: hardly
# Actual: asked
# Correct: False
#
# Sentence: is such as we might expect it ran if i remember right
# Predicted: and
# Actual: sent
# Correct: False
#
# Sentence: the principal room while i still
# Predicted: just
# Actual: observed
# Correct: False
#
# Sentence: some of the details are of
# Predicted: your
# Actual: interest
# Correct: False
#
# Sentence: other side a blow was struck and
# Predicted: of
# Actual: in
# Correct: False
#
# Sentence: been lifted and conveyed
# Predicted: to
# Actual: somewhere
# Correct: False
#
# Sentence: from the goose and
# Predicted: that
# Actual: the
# Correct: False
#
# Sentence: these
# Predicted: little
# Actual: perils
# Correct: False
#
# Sentence: of him but
# Predicted: the
# Actual: sherlock
# Correct: False
#
# Sentence: sister julia and i were
# Predicted: shown
# Actual: twins
# Correct: False
#
# Sentence: my gun and held him in my arms but
# Predicted: i
# Actual: he
# Correct: False
#
# Sentence: the effect of causing some little nervous disturbance
# Predicted: in
# Actual: in
# Correct: True
#
# Sentence: squalid beggar and in the evenings transform
# Predicted: into
# Actual: myself
# Correct: False
#
# Sentence: grasp and turned as pale as death i snatched
# Predicted: his
# Actual: it
# Correct: False
#
# Sentence: my anger mary
# Predicted: the
# Actual: was
# Correct: False
#
# Sentence: may give him
# Predicted: to
# Actual: a
# Correct: False
#
# Sentence: wound of mine i should be surprised if they believed my
# Predicted: father
# Actual: statement
# Correct: False
#
# Sentence: maiden is not so much angry as perplexed or
# Predicted: twelve
# Actual: grieved
# Correct: False
#
# Sentence: arthur who had stood sullenly with his arms folded
# Predicted: me
# Actual: asked
# Correct: False
#
# Sentence: became absolutely clear she had gone off with a man and
# Predicted: looking
# Actual: the
# Correct: False
#
# Sentence: blockaded the house and having met you succeeded by
# Predicted: winding
# Actual: certain
# Correct: False
#
# Sentence: a cigar and waited behind a tree until he should be
# Predicted: less
# Actual: alone
# Correct: False
#
# Sentence: precisely so i ought to know its size and
# Predicted: to
# Actual: shape
# Correct: False
#
# Sentence: visit to warsaw i
# Predicted: got
# Actual: made
# Correct: False
#
# Sentence: during those
# Predicted: singular
# Actual: months
# Correct: False
#
# Sentence: be little relation between the
# Predicted: more
# Actual: different
# Correct: False
#
# Sentence: moments notice to me with my nerves worked up to
# Predicted: me
# Actual: a
# Correct: False
#
# Sentence: your own little income he asked does it
# Predicted: he
# Actual: come
# Correct: False
#
# Sentence: bedroom my
# Predicted: cup
# Actual: companion
# Correct: False
#
# Sentence: there is a field for the observation
# Predicted: i
# Actual: and
# Correct: False
#
# Sentence: weddingdress of watered silk a pair of white
# Predicted: cardboard
# Actual: satin
# Correct: False
#
# Sentence: this dress
# Predicted: i
# Actual: does
# Correct: False
#
# Sentence: upon this metal floor there are
# Predicted: found
# Actual: small
# Correct: False
#
# Sentence: ruefully it was a very ordinary black hat of the usual round
# Predicted: but
# Actual: shape
# Correct: False
#
# Sentence: lives in
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: down his arms my uncle returned to his plantation
# Predicted: when
# Actual: where
# Correct: False
#
# Sentence: there the matter stands
# Predicted: thus
# Actual: at
# Correct: False
#
# Sentence: always the way folk who were in grief came to my wife like birds
# Predicted: these
# Actual: to
# Correct: False
#
# Sentence: her ways so that it was evident
# Predicted: with
# Actual: that
# Correct: False
#
# Sentence: would be a purveyor
# Predicted: between
# Actual: to
# Correct: False
#
# Sentence: it was very sweet of you
# Predicted: and
# Actual: to
# Correct: False
#
# Sentence: wound dressed and then the doctor was kind enough to
# Predicted: get
# Actual: bring
# Correct: False
#
# Sentence: second son
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: blow does not beget sympathy and indignation among the
# Predicted: richest
# Actual: neighbours
# Correct: False
#
# Sentence: what else can be indicated by that
# Predicted: we
# Actual: right
# Correct: False
#
# Sentence: how can we have when i saw him with
# Predicted: her
# Actual: my
# Correct: False
#
# Sentence: opened and we were shown
# Predicted: into
# Actual: up
# Correct: False
#
# Sentence: up to briony
# Predicted: lodge
# Actual: lodge
# Correct: True
#
# Sentence: that
# Predicted: is
# Actual: which
# Correct: False
#
# Sentence: and so they have the
# Predicted: lascar
# Actual: use
# Correct: False
#
# Sentence: heard a metallic clang which might have been caused by one of
# Predicted: the
# Actual: those
# Correct: False
#
# Sentence: compliment
# Predicted: a
# Actual: you
# Correct: False
#
# Sentence: misgivings of
# Predicted: some
# Actual: the
# Correct: False
#
# Sentence: well i did what she said
# Predicted: to
# Actual: mr
# Correct: False
#
# Sentence: window and again i laughed very heartily at the
# Predicted: door
# Actual: funny
# Correct: False
#
# Sentence: i see that
# Predicted: there
# Actual: you
# Correct: False
#
# Sentence: daily seat crosslegged with his
# Predicted: long
# Actual: tiny
# Correct: False
#
# Sentence: was not a
# Predicted: good
# Actual: clean
# Correct: False
#
# Sentence: met the eye
# Predicted: like
# Actual: holmes
# Correct: False
#
# Sentence: i have heard
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: oh yes i did you remember in her
# Predicted: before
# Actual: statement
# Correct: False
#
# Sentence: i must really ask you to be
# Predicted: more
# Actual: a
# Correct: False
#
# Sentence: despair if his motives were
# Predicted: in
# Actual: innocent
# Correct: False
#
# Sentence: carry my stone to kilburn there was a little shed in the yard
# Predicted: to
# Actual: and
# Correct: False
#
# Sentence: cloak went down to the office which is about half
# Predicted: an
# Actual: a
# Correct: False
#
# Sentence: west i had no
# Predicted: doubt
# Actual: idea
# Correct: False
#
# Sentence: last man to see the gentleman of
# Predicted: some
# Actual: whom
# Correct: False
#
# Sentence: choked and we
# Predicted: came
# Actual: got
# Correct: False
#
# Sentence: could not imagine it seemed altogether past belief that anyone
# Predicted: was
# Actual: could
# Correct: False
#
# Sentence: for
# Predicted: the
# Actual: half
# Correct: False
#
# Sentence: back and in spite of the continued resistance of
# Predicted: my
# Actual: the
# Correct: False
#
# Sentence: that mccarthy senior met his death from mccarthy
# Predicted: he
# Actual: junior
# Correct: False
#
# Sentence: and
# Predicted: i
# Actual: looking
# Correct: False
#
# Sentence: making inquiries said holmes carelessly if you wont tell us
# Predicted: what
# Actual: the
# Correct: False
#
# Sentence: it is true that i
# Predicted: am
# Actual: have
# Correct: False
#
# Sentence: path and walked over the edge of one
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: i fail to see
# Predicted: a
# Actual: that
# Correct: False
#
# Sentence: we reached the lawn crossed it and were about
# Predicted: four
# Actual: to
# Correct: False
#
# Sentence: yes
# Predicted: but
# Actual: certainly
# Correct: False
#
# Sentence: ah
# Predicted: said
# Actual: that
# Correct: False
#
# Sentence: nothing except the
# Predicted: scotland
# Actual: criminal
# Correct: False
#
# Sentence: it must be to him to be
# Predicted: able
# Actual: upbraided
# Correct: False
#
# Sentence: was a middlesized man coarsely clad as became
# Predicted: in
# Actual: his
# Correct: False
#
# Sentence: quite
# Predicted: so
# Actual: so
# Correct: True
#
# Sentence: singular chance has
# Predicted: young
# Actual: placed
# Correct: False
#
# Sentence: only been to the
# Predicted: left
# Actual: side
# Correct: False
#
# Sentence: the family of lord robert st simon has been thrown
# Predicted: now
# Actual: into
# Correct: False
#
# Sentence: threw off my clothes pulled on those of
# Predicted: a
# Actual: a
# Correct: True
#
# Sentence: very
# Predicted: good
# Actual: little
# Correct: False
#
# Sentence: staples it
# Predicted: occurred
# Actual: is
# Correct: False
#
# Sentence: when i would leave him stooping over a
# Predicted: paper
# Actual: retort
# Correct: False
#
# Sentence: feared to refer them to
# Predicted: a
# Actual: you
# Correct: False
#
# Sentence: more
# Predicted: interesting
# Actual: to
# Correct: False
#
# Sentence: should be proud to
# Predicted: a
# Actual: see
# Correct: False
#
# Sentence: that
# Predicted: is
# Actual: he
# Correct: False
#
# Sentence: invent a cause of
# Predicted: course
# Actual: quarrel
# Correct: False
#
# Sentence: there are one or two points in it which are
# Predicted: you
# Actual: suggestive
# Correct: False
#
# Sentence: lestrade looked sadly at my companion then
# Predicted: he
# Actual: he
# Correct: True
#
# Sentence: a slow and
# Predicted: such
# Actual: heavy
# Correct: False
#
# Sentence: sundials and papers i shall
# Predicted: live
# Actual: take
# Correct: False
#
# Sentence: the wild scream of a terrified woman
# Predicted: was
# Actual: i
# Correct: False
#
# Sentence: metal bars that secured the shutters falling back
# Predicted: into
# Actual: into
# Correct: True
#
# Sentence: in town the earliest risers were just
# Predicted: a
# Actual: beginning
# Correct: False
#
# Sentence: blonde woman stood in the opening clad
# Predicted: some
# Actual: in
# Correct: False
#
# Sentence: one horse interjected
# Predicted: his
# Actual: holmes
# Correct: False
#
# Sentence: the wicket gate however i found my acquaintance
# Predicted: and
# Actual: of
# Correct: False
#
# Sentence: you will excuse my beginning without you watson said he but
# Predicted: to
# Actual: you
# Correct: False
#
# Sentence: expectancy there was something depressing and subduing in the
# Predicted: corner
# Actual: sudden
# Correct: False
#
# Sentence: from a journey to a patient for i
# Predicted: saw
# Actual: had
# Correct: False
#
# Sentence: evening
# Predicted: before
# Actual: papers
# Correct: False
#
# Sentence: pompous and
# Predicted: shaking
# Actual: slow
# Correct: False
#
# Sentence: stretched out
# Predicted: little
# Actual: to
# Correct: False
#
# Sentence: they have been married about seven
# Predicted: of
# Actual: years
# Correct: False
#
# Sentence: is the slip and
# Predicted: this
# Actual: here
# Correct: False
#
# Sentence: salary beforehand so that they
# Predicted: were
# Actual: may
# Correct: False
#
# Sentence: between the years 82 and 90 i
# Predicted: knew
# Actual: am
# Correct: False
#
# Sentence: the reaction of joy was as
# Predicted: he
# Actual: passionate
# Correct: False
#
# Sentence: on the top
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: blood by
# Predicted: the
# Actual: direct
# Correct: False
#
# Sentence: and i to find
# Predicted: you
# Actual: an
# Correct: False
#
# Sentence: of footsteps moving softly
# Predicted: to
# Actual: in
# Correct: False
#
# Sentence: as i waited i lifted the unopened newspaper
# Predicted: and
# Actual: from
# Correct: False
#
# Sentence: made his way along the track which
# Predicted: i
# Actual: ran
# Correct: False
#
# Sentence: could see the windows of this
# Predicted: tangled
# Actual: part
# Correct: False
#
# Sentence: dislike to the lad but his blood was in
# Predicted: half
# Actual: him
# Correct: False
#
# Sentence: roll from his
# Predicted: pocket
# Actual: pocket
# Correct: True
#
# Sentence: of either mr william morris or mr duncan
# Predicted: ross
# Actual: ross
# Correct: True
#
# Sentence: this
# Predicted: is
# Actual: is
# Correct: True
#
# Sentence: the wheels
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: but it is impossible said miss hunter the ladder
# Predicted: come
# Actual: was
# Correct: False
#
# Sentence: i came to you sir because i heard of you
# Predicted: and
# Actual: from
# Correct: False
#
# Sentence: i am very much afraid that it is not
# Predicted: hatherley
# Actual: but
# Correct: False
#
# Sentence: why
# Predicted: did
# Actual: should
# Correct: False
#
# Sentence: few days and which he anoints with
# Predicted: his
# Actual: limecream
# Correct: False
#
# Sentence: provoked a quick
# Predicted: brilliant
# Actual: impatient
# Correct: False
#
# Sentence: but it might
# Predicted: have
# Actual: have
# Correct: True
#
# Sentence: from america as to what it was he
# Predicted: was
# Actual: feared
# Correct: False
#
# Sentence: after pa thought i
# Predicted: fancy
# Actual: had
# Correct: False
#
# Sentence: and got
# Predicted: as
# Actual: my
# Correct: False
#
# Sentence: i begin to think watson
# Predicted: he
# Actual: said
# Correct: False
#
# Sentence: have exacted from you
# Predicted: before
# Actual: should
# Correct: False
#
# Sentence: welltodo within
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: husband you
# Predicted: work
# Actual: found
# Correct: False
#
# Sentence: you must have read about lord st simon
# Predicted: bitterly
# Actual: and
# Correct: False
#
# Sentence: of
# Predicted: his
# Actual: us
# Correct: False
#
# Sentence: satisfaction than his
# Predicted: son
# Actual: words
# Correct: False
#
# Sentence: and about
# Predicted: the
# Actual: his
# Correct: False
#
# Sentence: blockaded the house and
# Predicted: drove
# Actual: having
# Correct: False
#
# Sentence: while to me the whole business was still
# Predicted: of
# Actual: confused
# Correct: False
#
# Sentence: mr hatherley said he with something of
# Predicted: it
# Actual: a
# Correct: False
#
# Sentence: indeed this is more
# Predicted: likely
# Actual: interesting
# Correct: False
#
# Sentence: leave him goodbye and god help
# Predicted: me
# Actual: you
# Correct: False
#
# Sentence: were ready he moved out
# Predicted: of
# Actual: yesterday
# Correct: False
#
# Sentence: been committed and that therefore i
# Predicted: had
# Actual: am
# Correct: False
#
# Sentence: the entrance on the right side was a
# Predicted: small
# Actual: small
# Correct: True
#
# Sentence: lens in his
# Predicted: affairs
# Actual: pocket
# Correct: False
#
# Sentence: the ground but even the bark of the tree as far
# Predicted: as
# Actual: as
# Correct: True
#
# Sentence: scotland
# Predicted: yard
# Actual: yard
# Correct: True
#
# Sentence: he
# Predicted: is
# Actual: had
# Correct: False
#
# Sentence: the last time you
# Predicted: have
# Actual: said
# Correct: False
#
# Sentence: stoner you see that we
# Predicted: shall
# Actual: have
# Correct: False
#
# Sentence: it seems
# Predicted: that
# Actual: to
# Correct: False
#
# Sentence: large
# Predicted: one
# Actual: towns
# Correct: False
#
# Sentence: is confined to that when you
# Predicted: hear
# Actual: raise
# Correct: False
#
# Sentence: very deepest moment your recent services to one of the
# Predicted: it
# Actual: royal
# Correct: False
#
# Sentence: its numerous glassfactories and papermills ha
# Predicted: my
# Actual: ha
# Correct: False
#
# Sentence: take them at a disadvantage they
# Predicted: were
# Actual: may
# Correct: False
#
# Sentence: which i wished to
# Predicted: see
# Actual: be
# Correct: False
#
# Sentence: watching me eagerly out of his small eyes and i could
# Predicted: not
# Actual: see
# Correct: False
#
# Sentence: even to you
# Predicted: see
# Actual: who
# Correct: False
#
# Sentence: three gems
# Predicted: which
# Actual: had
# Correct: False
#
# Sentence: the grass within a
# Predicted: pair
# Actual: few
# Correct: False
#
# Sentence: carved
# Predicted: so
# Actual: upon
# Correct: False
#
# Sentence: and now i have a very strange experience to tell you i
# Predicted: can
# Actual: had
# Correct: False
#
# Sentence: lost nothing but energy can save you
# Predicted: are
# Actual: this
# Correct: False
#
# Sentence: this moment
# Predicted: from
# Actual: i
# Correct: False
#
# Sentence: that you may get away or perhaps that you may
# Predicted: imagine
# Actual: conceal
# Correct: False
#
# Sentence: his head against the wall with
# Predicted: a
# Actual: such
# Correct: False
#
# Sentence: god help me i would not have them ashamed of their father
# Predicted: hum
# Actual: my
# Correct: False
#
# Sentence: where we hired
# Predicted: do
# Actual: a
# Correct: False
#
# Sentence: assistance in the case of
# Predicted: her
# Actual: the
# Correct: False
#
# Sentence: humming a tune under my breath to keep up my spirits and feeling
# Predicted: one
# Actual: that
# Correct: False
#
# Sentence: into the cab and i shall soon
# Predicted: set
# Actual: be
# Correct: False
#
# Sentence: murdertrap on the whole riverside and
# Predicted: its
# Actual: i
# Correct: False
#
# Sentence: sometimes curious as to their masters affairs now we can
# Predicted: all
# Actual: talk
# Correct: False
#
# Sentence: then we have stopped all
# Predicted: if
# Actual: the
# Correct: False
#
# Sentence: did to his unhappy father but still i had such
# Predicted: a
# Actual: faith
# Correct: False
#
# Sentence: as cunning as
# Predicted: rather
# Actual: his
# Correct: False
#
# Sentence: one of the most absolute fools
# Predicted: eye
# Actual: in
# Correct: False
#
# Sentence: ventured a
# Predicted: shadow
# Actual: remark
# Correct: False
#
# Sentence: interesting ourselves
# Predicted: which
# Actual: in
# Correct: False
#
# Sentence: of importance that it should
# Predicted: unnecessary
# Actual: not
# Correct: False
#
# Sentence: interfere come what may
# Predicted: be
# Actual: you
# Correct: False
#
# Sentence: you when
# Predicted: it
# Actual: they
# Correct: False
#
# Sentence: results the matter is
# Predicted: all
# Actual: a
# Correct: False
#
# Sentence: these little records of our cases which you have
# ...
# Actual: not
# Correct: False
#
# Sentence: had run swiftly and as his tread was marked in
# Predicted: front
# Actual: places
# Correct: False
#
# Sentence: understand that this register and diary may
# Predicted: be
# Actual: implicate
# Correct: False
#
# Sentence: adventuress irene adler the
# Predicted: money
# Actual: name
# Correct: False
#
# Sentence: this discovery and the evident confusion
# Predicted: from
# Actual: which
# Correct: False
#
# Sentence: what
# Predicted: is
# Actual: would
# Correct: False
#
# Sentence: and the
# Predicted: two
# Actual: punishment
# Correct: False
#
# Sentence: sufferer it was not until close upon six oclock that
# Predicted: afternoon
# Actual: i
# Correct: False
#
# Sentence: twice my boy has
# Predicted: been
# Actual: asked
# Correct: False
#
# Sentence: in
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: ways and simple
# Predicted: a
# Actual: life
# Correct: False
#
# Sentence: through the skylight we shall soon see how he
# Predicted: put
# Actual: managed
# Correct: False
#
# Sentence: beggary and
# Predicted: chair
# Actual: he
# Correct: False
#
# Sentence: stump among the moss where he had tossed
# Predicted: it
# Actual: it
# Correct: True
#
# Sentence: let us now see the letter ha there
# Predicted: is
# Actual: has
# Correct: False
#
# Sentence: the
# Predicted: coroner
# Actual: unfortunate
# Correct: False
#
# Sentence: capital between your brandy and your bandage i feel a new
# Predicted: leaf
# Actual: man
# Correct: False
#
# Sentence: the church but
# Predicted: asking
# Actual: not
# Correct: False
#
# Sentence: then he
# Predicted: turned
# Actual: has
# Correct: False
#
# Sentence: the weird business of the
# Predicted: sinister
# Actual: sign
# Correct: False
#
# Sentence: and halfpennies421 pennies
# Predicted: there
# Actual: and
# Correct: False
#
# Sentence: two
# Predicted: of
# Actual: years
# Correct: False
#
# Sentence: and heavy with the
# Predicted: outside
# Actual: brown
# Correct: False
#
# Sentence: miserable secret as
# Predicted: a
# Actual: a
# Correct: True
#
# Sentence: now my theory all along has been
# Predicted: upon
# Actual: that
# Correct: False
#
# Sentence: sudden ejaculation caused me to wake up and i
# Predicted: had
# Actual: found
# Correct: False
#
# Sentence: immense
# Predicted: a
# Actual: strength
# Correct: False
#
# Sentence: and that is
# Predicted: very
# Actual: absolutely
# Correct: False
#
# Sentence: just as he was in his bare feet opened the window
# Predicted: she
# Actual: sprang
# Correct: False
#
# Sentence: as he spoke he drew the dogwhip swiftly from the dead mans
# Predicted: body
# Actual: lap
# Correct: False
#
# Sentence: sherlock holmes sprang out of his chair as if he had been
# Predicted: on
# Actual: galvanised
# Correct: False
#
# Sentence: so i
# Predicted: heard
# Actual: am
# Correct: False
#
# Sentence: boardingschools i think that i have touched
# Predicted: by
# Actual: bottom
# Correct: False
#
# Sentence: such as they are they are set forth in a
# Predicted: note
# Actual: single
# Correct: False
#
# Sentence: faces and one yellow light twinkling in front of us through
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: germans i know also that they were all three away from the
# Predicted: day
# Actual: ship
# Correct: False
#
# Sentence: should be a marriage between us james and i
# Predicted: have
# Actual: have
# Correct: True
#
# Sentence: a slight motion to me to approach him and instantly as he
# Predicted: was
# Actual: turned
# Correct: False
#
# Sentence: never
# Predicted: permit
# Actual: said
# Correct: False
#
# Sentence: company
# Predicted: of
# Actual: with
# Correct: False
#
# Sentence: and turning away without
# Predicted: three
# Actual: observing
# Correct: False
#
# Sentence: well you have to be in the office
# Predicted: at
# Actual: or
# Correct: False
#
# Sentence: communication between them
# Predicted: and
# Actual: but
# Correct: False
#
# Sentence: brought a tinge of colour into his cheeks and
# Predicted: his
# Actual: he
# Correct: False
#
# Sentence: this
# Predicted: is
# Actual: looks
# Correct: False
#
# Sentence: the twisted lip which
# Predicted: are
# Actual: had
# Correct: False
#
# Sentence: large masses of
# Predicted: his
# Actual: nickel
# Correct: False
#
# Sentence: unsystematic sensational
# Predicted: that
# Actual: literature
# Correct: False
#
# Sentence: i did as i was told and
# Predicted: i
# Actual: at
# Correct: False
#
# Sentence: out on the table this is a map of the colony of victoria he
# Predicted: was
# Actual: said
# Correct: False
#
# Sentence: on the scene of action we lunch at swindon
# Predicted: when
# Actual: and
# Correct: False
#
# Sentence: my attainments i painted my face and to
# Predicted: him
# Actual: make
# Correct: False
#
# Sentence: flamecoloured silk
# Predicted: a
# Actual: and
# Correct: False
#
# Sentence: absolutely follow my advice in every
# Predicted: way
# Actual: respect
# Correct: False
#
# Sentence: was a long thin sadfaced man with a very shiny hat
# Predicted: upon
# Actual: and
# Correct: False
#
# Sentence: drove home
# Predicted: to
# Actual: to
# Correct: True
#
# Sentence: room his features were gravely set
# Predicted: there
# Actual: but
# Correct: False
#
# Sentence: companion we soothed and comforted her by such words as we
# Predicted: were
# Actual: could
# Correct: False
#
# Sentence: the meaning of
# Predicted: it
# Actual: this
# Correct: False
#
# Sentence: he had hardly spoken before there rushed into the room
# Predicted: which
# Actual: one
# Correct: False
#
# Sentence: side and
# Predicted: looked
# Actual: left
# Correct: False
#
# Sentence: so much
# Predicted: for
# Actual: for
# Correct: True
#
# Sentence: coronet in his hands rushed back closed the window ascended
# Predicted: are
# Actual: to
# Correct: False
#
# Sentence: right on to the other block and now doctor weve done our work
# Predicted: it
# Actual: so
# Correct: False
#
# Sentence: he was a very shy man mr holmes he would rather walk
# Predicted: to
# Actual: with
# Correct: False
#
# Sentence: oh yes i know that i have treated
# Predicted: had
# Actual: you
# Correct: False
#
# Sentence: this great panoply she peeped up in a nervous hesitating
# Predicted: at
# Actual: fashion
# Correct: False
#
# Sentence: shabbygenteel place
# Predicted: and
# Actual: where
# Correct: False
#
# Sentence: persuaded him to forgo his bohemian habits so
# Predicted: simple
# Actual: far
# Correct: False
#
# Sentence: ha this
# Predicted: ring
# Actual: may
# Correct: False
#
# Sentence: is not the gritty grey dust of the street but the fluffy
# Predicted: all
# Actual: brown
# Correct: False
#
# Sentence: platform
# Predicted: was
# Actual: in
# Correct: False
#
# Sentence: unable to follow you for example how did you deduce that this
# Predicted: is
# Actual: man
# Correct: False
#
# Sentence: and my duties sir i should be glad to know
# Predicted: what
# Actual: what
# Correct: True
#
# Sentence: oversight so i took out my bunch of
# Predicted: course
# Actual: keys
# Correct: False
#
# Sentence: undoubtedly
# Predicted: some
# Actual: so
# Correct: False
#
# Sentence: oh
# Predicted: yes
# Actual: no
# Correct: False
#
# Sentence: and driving from the country of those who were opposed to
# Predicted: me
# Actual: its
# Correct: False
#
# Sentence: letter unobserved probably he
# Predicted: could
# Actual: handed
# Correct: False
#
# Sentence: concisely to you watson
# Predicted: he
# Actual: and
# Correct: False
#
# Sentence: it would be injustice
# Predicted: of
# Actual: to
# Correct: False
#
# Sentence: must be someone from america because she had spent so
# Predicted: kindly
# Actual: short
# Correct: False
#
# Sentence: man with a sharp face and trim sidewhiskers was
# Predicted: a
# Actual: helping
# Correct: False
#
# Sentence: his own
# Predicted: save
# Actual: highpower
# Correct: False
#
# Sentence: distrusted so i think and so too
# Predicted: little
# Actual: thinks
# Correct: False
#
# Sentence: disappearance of the
# Predicted: room
# Actual: bride
# Correct: False
#
# Sentence: must have something
# Predicted: else
# Actual: in
# Correct: False
#
# Sentence: besides ourselves who are anxious about the matter and i
# Predicted: stay
# Actual: should
# Correct: False
#
# Sentence: thank you said holmes
# Predicted: folding
# Actual: i
# Correct: False
#
# Sentence: the key
# Predicted: was
# Actual: upon
# Correct: False
#
# Sentence: no sir but i want to find out about
# Predicted: bed
# Actual: them
# Correct: False
#
# Sentence: they were very old hands but now thanks to this
# Predicted: lady
# Actual: lucky
# Correct: False
#
# Sentence: study in scarlet to work out
# Predicted: in
# Actual: the
# Correct: False
#
# Sentence: then had having
# Predicted: no
# Actual: measured
# Correct: False
#
# Sentence: should your son allow himself to be accused in their place
# Predicted: and
# Actual: there
# Correct: False
#
# Sentence: excuse me i know everything of it
# Predicted: i
# Actual: you
# Correct: False
#
# Sentence: he has come back and done it i tell
# Predicted: him
# Actual: you
# Correct: False
#
# Sentence: and holmes
# Predicted: had
# Actual: fears
# Correct: False
#
# Sentence: youll never persuade me to
# Predicted: be
# Actual: believe
# Correct: False
#
# Sentence: whether the spotted handkerchiefs which so
# Predicted: of
# Actual: many
# Correct: False
#
# Sentence: it
# Predicted: was
# Actual: is
# Correct: False
#
# Sentence: knowing my past than of the police whatever he wanted he must
# Predicted: have
# Actual: have
# Correct: True
#
# Sentence: found myself lying upon the stone
# Predicted: in
# Actual: floor
# Correct: False
#
# Sentence: the signal to throw in this object then to raise the cry
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: old clergyman but you know i have been trained as
# Predicted: to
# Actual: an
# Correct: False
#
# Sentence: matter until he
# Predicted: came
# Actual: heard
# Correct: False
#
# Sentence: my arms to cover
# Predicted: and
# Actual: my
# Correct: False
#
# Sentence: process of deduction when i hear you give your
# Predicted: advice
# Actual: reasons
# Correct: False
#
# Sentence: of considerably more value than if it were made of solid
# Predicted: by
# Actual: gold
# Correct: False
#
# Sentence: you now he said as he turned hungrily on the simple fare that
# Predicted: he
# Actual: our
# Correct: False
#
# Sentence: retired
# Predicted: to
# Actual: to
# Correct: True
#
# Sentence: face behind it until the comical side of the affair so
# Predicted: it
# Actual: completely
# Correct: False
#
# Sentence: holmes
# Predicted: turned
# Actual: chuckled
# Correct: False
#
# Sentence: especially as rather against the
# Predicted: money
# Actual: strict
# Correct: False
#
# Sentence: interview but he is now dead and there is every
# Predicted: reason
# Actual: prospect
# Correct: False
#
# Sentence: i should be happy to advance it without further parley
# Predicted: that
# Actual: from
# Correct: False
#
# Sentence: whence he could see what passed in the
# Predicted: force
# Actual: hall
# Correct: False
#
# Sentence: have you a couple of days to spare have
# Predicted: been
# Actual: just
# Correct: False
#
# Sentence: is there a cellar with a
# Predicted: very
# Actual: good
# Correct: False
#
# Sentence: have
# Predicted: you
# Actual: written
# Correct: False
#
# Sentence: his grip has been upon me these twenty years and he has
# Predicted: been
# Actual: blasted
# Correct: False
#
# Sentence: questioning gaze
# Predicted: and
# Actual: and
# Correct: True
#
# Sentence: explain afterwards
# Predicted: if
# Actual: i
# Correct: False
#
# Sentence: for an instant threw up her hands with a
# Predicted: head
# Actual: despairing
# Correct: False
#
# Sentence: only
# Predicted: the
# Actual: been
# Correct: False
#
# Sentence: or to
# Predicted: sit
# Actual: cut
# Correct: False
#
# Sentence: sleeves and fronts
# Predicted: were
# Actual: of
# Correct: False
#
# Sentence: the garden behind into the stable lane
# Predicted: a
# Actual: so
# Correct: False
#
# Sentence: hes a
# Predicted: remarkable
# Actual: brave
# Correct: False
#
# Sentence: height slim
# Predicted: that
# Actual: with
# Correct: False
#
# Sentence: for a higher stake tonight than you have ever done
# Predicted: no
# Actual: yet
# Correct: False
#
# Sentence: i met
# Predicted: him
# Actual: in
# Correct: False
#
# Sentence: himself up onto the roof ah
# Predicted: and
# Actual: yes
# Correct: False
#
# Sentence: and a pair of bushy whiskers sunk that clear voice
# Predicted: an
# Actual: into
# Correct: False
#
# Sentence: smart fellow that observed holmes as we walked away he is
# Predicted: in
# Actual: in
# Correct: True
#
# Sentence: brought up upon the
# Predicted: room
# Actual: charge
# Correct: False
#
# Sentence: obvious facts that
# Predicted: there
# Actual: he
# Correct: False
#
# Sentence: to the left
# Predicted: as
# Actual: of
# Correct: False
#
# Sentence: snow and his
# Predicted: own
# Actual: features
# Correct: False
#
# Sentence: that
# Predicted: is
# Actual: the
# Correct: False
#
# Sentence: and who is this captain
# Predicted: mccarthy
# Actual: calhoun
# Correct: False
#
# Sentence: was as the
# Predicted: passage
# Actual: inspector
# Correct: False
#
# Sentence: it its the big white one over yonder theres twentysix
# Predicted: the
# Actual: of
# Correct: False
#
# Sentence: thinks that it might be of some assistance i will call at
# Predicted: last
# Actual: four
# Correct: False
#
# Sentence: down the rope and land on the bed
# Predicted: the
# Actual: it
# Correct: False
#
# Sentence: sherlock holmes and i surveyed this curt announcement
# Predicted: i
# Actual: and
# Correct: False
#
# Sentence: strong smell of burning oil and heated metal someone
# Predicted: with
# Actual: in
# Correct: False
#
# Sentence: may start with a strong presumption that colonel openshaw had
# Predicted: passed
# Actual: some
# Correct: False
#
# Sentence: was a member
# Predicted: from
# Actual: of
# Correct: False
#
# Sentence: points on which
# Predicted: asked
# Actual: i
# Correct: False
#
# Sentence: to have be the holder of them who it may
# Predicted: be
# Actual: in
# Correct: False
#
# Sentence: it
# Predicted: was
# Actual: is
# Correct: False
#
# Sentence: yes said holmes answering
# Predicted: she
# Actual: the
# Correct: False
#
# Sentence: you
# Predicted: have
# Actual: no
# Correct: False
#
# Sentence: the fashion of old
# Predicted: gold
# Actual: countryhouses
# Correct: False
#
# Sentence: sallow cheeks and a nervous clasping and unclasping of his long
# Predicted: thin
# Actual: thin
# Correct: True
#
# Sentence: oh no not now i shall have to tell my tale to the
# Predicted: other
# Actual: police
# Correct: False
#
# Sentence: vague impression that as i ran forward something lay
# Predicted: our
# Actual: upon
# Correct: False
#
# Sentence: information in
# Predicted: be
# Actual: this
# Correct: False
#
# Sentence: continents you are brought in
# Predicted: one
# Actual: contact
# Correct: False
#
# Sentence: street and so through
# Predicted: a
# Actual: wigmore
# Correct: False
#
# Sentence: as long as she was on the scene he could not take any action
# Predicted: yet
# Actual: without
# Correct: False
#
# Sentence: i shall see you at
# Predicted: all
# Actual: horsham
# Correct: False
#
# Sentence: a morose
# Predicted: one
# Actual: and
# Correct: False
#
# Sentence: feet i was at once convinced from what you had told me that
# Predicted: i
# Actual: the
# Correct: False
#
# Sentence: readyhanded criminal agent as
# Predicted: we
# Actual: it
# Correct: False
#
# Sentence: exceedingly
# Predicted: unfortunate
# Actual: grave
# Correct: False
#
# Sentence: muzzle buried
# Predicted: in
# Actual: in
# Correct: True
#
# Sentence: little problems and since
# Predicted: me
# Actual: you
# Correct: False
#
# Sentence: hands frantically to her and then vanished from
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: streets of the little town finally
# Predicted: he
# Actual: returning
# Correct: False
#
# Sentence: merely because my friend dr watson has not
# Predicted: sent
# Actual: heard
# Correct: False
#
# Sentence: opened the
# Predicted: mans
# Actual: gladstone
# Correct: False
#
# Sentence: holder and i
# Predicted: have
# Actual: went
# Correct: False
#
# Sentence: else she could trust her own guardianship but she
# Predicted: has
# Actual: could
# Correct: False
#
# Sentence: like to
# Predicted: do
# Actual: see
# Correct: False
#
# Sentence: whom i was not
# Predicted: very
# Actual: in
# Correct: False
#
# Sentence: know no active enemies i know nothing further
# Predicted: i
# Actual: of
# Correct: False
#
# Sentence: narratives its effect is
# Predicted: dark
# Actual: much
# Correct: False
#
# Sentence: him that he was a prisoner he remarked that
# Predicted: they
# Actual: he
# Correct: False
#
# Sentence: manager and housekeeper yet as
# Predicted: a
# Actual: tender
# Correct: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 33
#      30                 correct_predictions += 1
#      31             total_predictions += 1
# ---> 33             time.sleep(3)  # Wait for 1 second between predictions
#      35 accuracy = correct_predictions / total_predictions
#      36 print(f'Validation Accuracy: {accuracy:.4f}')
#
# KeyboardInterrupt:

# %%
# Generate predictions
def predict_next_words(model, tokenizer, seed_text, next_words):
    for _ in range(next_words):
        token_list = [word_to_index[word] for word in tokenize(seed_text)]
        token_list = np.pad(token_list, (max_sequence_len - len(token_list), 0), mode='constant')
        token_list = torch.tensor(token_list[-max_sequence_len+1:], dtype=torch.long).unsqueeze(0).to(device)

        with torch.no_grad():
            predicted = model(token_list).argmax(dim=1).item()

        output_word = index_to_word[predicted]
        seed_text += " " + output_word

    return seed_text

# Verifica si hay una GPU disponible y, si no, usa la CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Mueve el modelo al dispositivo
model.to(device)

seed_text = "i do not know if i have been a"
next_words = 10
print(predict_next_words(model, word_to_index, seed_text, next_words))
# Out:
# i do not know if i have been a little too much responded his friend i have carry my
