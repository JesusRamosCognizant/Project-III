# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter
import re

PATH = "Project-III/data/sherlock-holm.es_stories_plain-text_advs.txt"

# Read the text file
with open(PATH, 'r', encoding='utf-8') as file:
    text = file.read()

# %%
# Tokenize the text
def tokenize(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    words = text.split()
    return words

tokens = tokenize(text)
word_counts = Counter(tokens)
vocab = sorted(word_counts, key=word_counts.get, reverse=True)
word_to_index = {word: index + 1 for index, word in enumerate(vocab)}
index_to_word = {index + 1: word for index, word in enumerate(vocab)}
total_words = len(word_to_index) + 1

# %%
# Create input-output pairs
input_sequences = []
for line in text.split('\n'):
    token_list = [word_to_index[word] for word in tokenize(line) if word in word_to_index]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
# Pad the sequences
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array([np.pad(seq, (max_sequence_len - len(seq), 0), mode='constant') for seq in input_sequences])

# %%
# Split the sequences into input (X) and output (y)
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# Convert output to one-hot encoded vectors
y = np.array(torch.nn.functional.one_hot(torch.tensor(y), num_classes=total_words))

# %%
# Create a custom Dataset class
class TextDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = torch.tensor(y, dtype=torch.float)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = TextDataset(X, y)

# Split dataset into training and validation sets (90% training, 10% validation)
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# Define the model
class NextWordPredictor(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim):
        super(NextWordPredictor, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm(x)
        x = x[:, -1, :]
        x = self.fc(x)
        return x

model = NextWordPredictor(total_words, 200, 256, total_words)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Train the model
epochs = 2
for epoch in range(epochs):
    model.train()
    for inputs, labels in train_dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels.argmax(dim=1))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')

torch.save(model.state_dict(), "model_state.pth")
# Out:
# Epoch 1/2, Loss: 6.034351825714111
# Epoch 2/2, Loss: 5.341306209564209

# %%
# Evaluate the model on the validation set
model.eval()
correct_predictions = 0
total_predictions = 0

with torch.no_grad():
    for inputs, labels in val_dataloader:
        outputs = model(inputs)
        predicted = outputs.argmax(dim=1)
        actual = labels.argmax(dim=1)
        correct_predictions += (predicted == actual).sum().item()
        total_predictions += labels.size(0)

accuracy = correct_predictions / total_predictions
print(f'Validation Accuracy: {accuracy:.4f}')
# Out:
# Validation Accuracy: 0.1432

# %%
import time

# Evaluate the model on the validation set
model.eval()
correct_predictions = 0
total_predictions = 0

with torch.no_grad():
    for inputs, labels in val_dataloader:
        outputs = model(inputs)
        predicted = outputs.argmax(dim=1)
        actual = labels.argmax(dim=1)

        # Display results
        for i in range(len(inputs)):
            input_sentence = " ".join([index_to_word[idx.item()] for idx in inputs[i] if idx.item() != 0])
            predicted_word = index_to_word[predicted[i].item()]
            actual_word = index_to_word[actual[i].item()]
            correct = predicted[i].item() == actual[i].item()
            print(f"Sentence: {input_sentence}")
            print(f"Predicted: {predicted_word}")
            print(f"Actual: {actual_word}")
            print(f"Correct: {correct}")
            print()

            if correct:
                correct_predictions += 1
            total_predictions += 1

            time.sleep(3)  # Wait for 1 second between predictions

accuracy = correct_predictions / total_predictions
print(f'Validation Accuracy: {accuracy:.4f}')
# Out:
# Sentence: like to vanish away and never see any of them againjust sending
# Predicted: in
# Actual: a
# Correct: False
#
# Sentence: why said i glancing up at my companion that
# Predicted: i
# Actual: was
# Correct: False
#
# Sentence: it is important also or at least the initials are
# Predicted: the
# Actual: so
# Correct: False
#
# Sentence: anger and the veins stood out
# Predicted: of
# Actual: at
# Correct: False
#
# Sentence: my wife is fond of a particular shade
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: the facts are quite
# Predicted: so
# Actual: recent
# Correct: False
#
# Sentence: insinuating manner and a pair of
# Predicted: the
# Actual: wonderfully
# Correct: False
#
# Sentence: but i can hardly be expected to make merry over
# Predicted: the
# Actual: them
# Correct: False
#
# Sentence: him by the idea that he was doing me on a wager well watson
# Predicted: i
# Actual: we
# Correct: False
#
# Sentence: back but this has broken him down completely
# Predicted: a
# Actual: he
# Correct: False
#
# Sentence: upstairs and a few minutes later i heard the slam of
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: call at halfpast
# Predicted: i
# Actual: ten
# Correct: False
#
# Sentence: impression at the second glance
# Predicted: of
# Actual: however
# Correct: False
#
# Sentence: yes sir and no later than this morning i went to
# Predicted: the
# Actual: my
# Correct: False
#
# Sentence: thank you said my patient but
# Predicted: i
# Actual: i
# Correct: True
#
# Sentence: for two days quick quick or itll be
# Predicted: a
# Actual: too
# Correct: False
#
# Sentence: of us so it was a close thing but we emptied four of their
# Predicted: own
# Actual: saddles
# Correct: False
#
# Sentence: the
# Predicted: other
# Actual: surgeon
# Correct: False
#
# Sentence: the presence of those
# Predicted: which
# Actual: bulky
# Correct: False
#
# Sentence: he held up a
# Predicted: little
# Actual: piece
# Correct: False
#
# Sentence: he was a lawyer that sounded ominous what was the relation
# Predicted: of
# Actual: between
# Correct: False
#
# Sentence: between ourselves
# Predicted: in
# Actual: if
# Correct: False
#
# Sentence: no idea that he was in front of me when about a hundred yards
# Predicted: of
# Actual: from
# Correct: False
#
# Sentence: in
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: oldfashioned
# Predicted: of
# Actual: shutters
# Correct: False
#
# Sentence: sat up in my chair and my wife laid her
# Predicted: to
# Actual: needlework
# Correct: False
#
# Sentence: overpleasant i was wondering what i should say to this dear
# Predicted: mr
# Actual: little
# Correct: False
#
# Sentence: no sound came from within and at the
# Predicted: other
# Actual: silence
# Correct: False
#
# Sentence: wanted to see if the missing piece were at the scene of
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: well your own good sense will suggest what measures
# Predicted: i
# Actual: i
# Correct: True
#
# Sentence: indeed i
# Predicted: have
# Actual: should
# Correct: False
#
# Sentence: intrusted to me i hardened
# Predicted: it
# Actual: my
# Correct: False
#
# Sentence: finger and held it out upon
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: were there gipsies in the plantation
# Predicted: of
# Actual: at
# Correct: False
#
# Sentence: upon me for 25
# Predicted: as
# Actual: i
# Correct: False
#
# Sentence: i only
# Predicted: a
# Actual: looked
# Correct: False
#
# Sentence: let
# Predicted: me
# Actual: me
# Correct: True
#
# Sentence: feature she impressed me
# Predicted: to
# Actual: neither
# Correct: False
#
# Sentence: told
# Predicted: me
# Actual: you
# Correct: False
#
# Sentence: not he could use her money
# Predicted: to
# Actual: when
# Correct: False
#
# Sentence: a loud thudding noise came from
# Predicted: the
# Actual: somewhere
# Correct: False
#
# Sentence: has sworn to
# Predicted: the
# Actual: have
# Correct: False
#
# Sentence: they have however allowed me a policeman
# Predicted: or
# Actual: who
# Correct: False
#
# Sentence: not at all i am
# Predicted: sure
# Actual: glad
# Correct: False
#
# Sentence: link in a
# Predicted: few
# Actual: series
# Correct: False
#
# Sentence: be as well for
# Predicted: the
# Actual: you
# Correct: False
#
# Sentence: cheetah was indeed at liberty
# Predicted: of
# Actual: far
# Correct: False
#
# Sentence: so homely a thing as a goose at one end of this chain we have
# Predicted: been
# Actual: at
# Correct: False
#
# Sentence: for the observerexcellent for drawing the veil from
# Predicted: the
# Actual: mens
# Correct: False
#
# Sentence: it was allimportant when a woman thinks that her house
# Predicted: and
# Actual: is
# Correct: False
#
# Sentence: a thing like a cleaver
# Predicted: face
# Actual: said
# Correct: False
#
# Sentence: points one is that the murdered man had an
# Predicted: old
# Actual: appointment
# Correct: False
#
# Sentence: passions save with a gibe
# Predicted: and
# Actual: and
# Correct: True
#
# Sentence: the mantelpiece here he is
# Predicted: a
# Actual: said
# Correct: False
#
# Sentence: stepped from her carriage was
# Predicted: a
# Actual: the
# Correct: False
#
# Sentence: i was
# Predicted: a
# Actual: thoroughly
# Correct: False
#
# Sentence: of bakers and some
# Predicted: little
# Actual: hundreds
# Correct: False
#
# Sentence: it was catherine cusack who told me of it said he in a
# Predicted: few
# Actual: crackling
# Correct: False
#
# Sentence: covered his face could not conceal its
# Predicted: a
# Actual: repulsive
# Correct: False
#
# Sentence: spite of the attempts
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: sofa
# Predicted: the
# Actual: to
# Correct: False
#
# Sentence: lay upon the sofa and tried to interest myself in a
# Predicted: little
# Actual: yellowbacked
# Correct: False
#
# Sentence: it here and may read it for
# Predicted: me
# Actual: yourself
# Correct: False
#
# Sentence: met his
# Predicted: head
# Actual: fate
# Correct: False
#
# Sentence: moment they will see that you are not there
# Predicted: in
# Actual: oh
# Correct: False
#
# Sentence: and wrists she
# Predicted: was
# Actual: stood
# Correct: False
#
# Sentence: knots that and a
# Predicted: little
# Actual: toothbrush
# Correct: False
#
# Sentence: and a very good
# Predicted: man
# Actual: thing
# Correct: False
#
# Sentence: however was leaning against the railings which bordered our
# Predicted: visitor
# Actual: field
# Correct: False
#
# Sentence: seedy and disreputable hardfelt hat much the worse for wear
# Predicted: i
# Actual: and
# Correct: False
#
# Sentence: became absolutely clear she had
# Predicted: been
# Actual: gone
# Correct: False
#
# Sentence: should ask his leave as he was only a few years older than me
# Predicted: to
# Actual: but
# Correct: False
#
# Sentence: threw himself down
# Predicted: the
# Actual: into
# Correct: False
#
# Sentence: a few things packed and my ulster ready i
# Predicted: have
# Actual: know
# Correct: False
#
# Sentence: to write
# Predicted: and
# Actual: every
# Correct: False
#
# Sentence: picked up in the
# Predicted: room
# Actual: wood
# Correct: False
#
# Sentence: in the direction of
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: into a grove at the highest point from amid
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: that
# Predicted: is
# Actual: the
# Correct: False
#
# Sentence: now i
# Predicted: have
# Actual: knew
# Correct: False
#
# Sentence: all this you
# Predicted: are
# Actual: made
# Correct: False
#
# Sentence: lacklustre eye turned upon the
# Predicted: table
# Actual: newcomer
# Correct: False
#
# Sentence: has always
# Predicted: been
# Actual: fallen
# Correct: False
#
# Sentence: distrusted so i think and so
# Predicted: that
# Actual: too
# Correct: False
#
# Sentence: to him on which he had to confess that i was
# Predicted: a
# Actual: right
# Correct: False
#
# Sentence: i am in
# Predicted: the
# Actual: hopes
# Correct: False
#
# Sentence: the charge
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: steel she has the face of the most beautiful of women
# Predicted: and
# Actual: and
# Correct: True
#
# Sentence: morning train to the care of her good aunt at
# Predicted: the
# Actual: harrow
# Correct: False
#
# Sentence: seldom goes out at other
# Predicted: side
# Actual: times
# Correct: False
#
# Sentence: myself liking to break in upon his thoughts
# Predicted: and
# Actual: before
# Correct: False
#
# Sentence: casket in which as it
# Predicted: was
# Actual: afterwards
# Correct: False
#
# Sentence: the name of the maker
# Predicted: of
# Actual: no
# Correct: False
#
# Sentence: thanking me on
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: analysis of the acetones as we may need to
# Predicted: be
# Actual: be
# Correct: True
#
# Sentence: agitated
# Predicted: and
# Actual: over
# Correct: False
#
# Sentence: exceptional advantages in my power of making up and
# Predicted: the
# Actual: also
# Correct: False
#
# Sentence: stone at once for i did not know at what moment the police might
# Predicted: be
# Actual: not
# Correct: False
#
# Sentence: the sky i have a caseful of cigarettes here which need
# Predicted: to
# Actual: smoking
# Correct: False
#
# Sentence: before
# Predicted: i
# Actual: you
# Correct: False
#
# Sentence: then you wont forgive me you wont shake hands
# Predicted: that
# Actual: before
# Correct: False
#
# Sentence: the stairs together we had hardly reached the hall
# Predicted: door
# Actual: when
# Correct: False
#
# Sentence: well watson said holmes when our visitor had left us what
# Predicted: i
# Actual: do
# Correct: False
#
# Sentence: ay bodies watson we should be rich men if we
# Predicted: shall
# Actual: had
# Correct: False
#
# Sentence: crime it is a subject to which i have devoted some
# Predicted: little
# Actual: little
# Correct: True
#
# Sentence: yes i fancy we may have some company dropping
# Predicted: i
# Actual: in
# Correct: False
#
# Sentence: beggary and
# Predicted: the
# Actual: he
# Correct: False
#
# Sentence: hampshire charming rural place
# Predicted: in
# Actual: the
# Correct: False
#
# Sentence: but i understand that all the other clothes were
# Predicted: to
# Actual: found
# Correct: False
#
# Sentence: i could do with
# Predicted: a
# Actual: much
# Correct: False
#
# Sentence: perhaps as well that the facts should now come to light for i
# Predicted: have
# Actual: have
# Correct: True
#
# Sentence: of
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: and
# Predicted: i
# Actual: of
# Correct: False
#
# Sentence: not at all this gentleman mr wilson has been my
# Predicted: friend
# Actual: partner
# Correct: False
#
# Sentence: both to her
# Predicted: and
# Actual: husband
# Correct: False
#
# Sentence: to the bush and in a word became what
# Predicted: i
# Actual: you
# Correct: False
#
# Sentence: insanely in love with her but
# Predicted: i
# Actual: some
# Correct: False
#
# Sentence: the offices round but none of them seemed to know anything about
# Predicted: the
# Actual: it
# Correct: False
#
# Sentence: the latter raise up his hand as
# Predicted: i
# Actual: if
# Correct: False
#
# Sentence: lay upon the sofa and tried to
# Predicted: be
# Actual: interest
# Correct: False
#
# Sentence: understand that i am not accustomed to
# Predicted: see
# Actual: doing
# Correct: False
#
# Sentence: the offices round but
# Predicted: i
# Actual: none
# Correct: False
#
# Sentence: red hair grew low over his
# Predicted: head
# Actual: eyes
# Correct: False
#
# Sentence: you
# Predicted: are
# Actual: appeared
# Correct: False
#
# Sentence: it was only a joke at
# Predicted: the
# Actual: first
# Correct: False
#
# Sentence: in the church
# Predicted: of
# Actual: she
# Correct: False
#
# Sentence: you fill me
# Predicted: that
# Actual: with
# Correct: False
#
# Sentence: bed beside
# Predicted: the
# Actual: him
# Correct: False
#
# Sentence: well have
# Predicted: been
# Actual: you
# Correct: False
#
# Sentence: is
# Predicted: a
# Actual: quite
# Correct: False
#
# Sentence: rather a trite one you will find parallel
# Predicted: to
# Actual: cases
# Correct: False
#
# Sentence: before and he dropped heavily into
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: and have you any
# Predicted: enough
# Actual: on
# Correct: False
#
# Sentence: perform one more feat i should not ask it of you if i
# Predicted: have
# Actual: did
# Correct: False
#
# Sentence: night the walls were carefully sounded
# Predicted: to
# Actual: and
# Correct: False
#
# Sentence: oakshott tonight or whether
# Predicted: i
# Actual: we
# Correct: False
#
# Sentence: the loss was a heavy one he was clearly so scared by
# Predicted: the
# Actual: his
# Correct: False
#
# Sentence: if that were
# Predicted: to
# Actual: he
# Correct: False
#
# Sentence: thank you maggie says i but if it is all
# Predicted: that
# Actual: the
# Correct: False
#
# Sentence: letters were to be forwarded to 226 gordon square so
# Predicted: i
# Actual: thither
# Correct: False
#
# Sentence: for they were
# Predicted: to
# Actual: always
# Correct: False
#
# Sentence: had when the fit was
# Predicted: a
# Actual: on
# Correct: False
#
# Sentence: brace of cold woodcock
# Predicted: and
# Actual: a
# Correct: False
#
# Sentence: torn at the
# Predicted: other
# Actual: forefinger
# Correct: False
#
# Sentence: i can do pretty well with what i
# Predicted: have
# Actual: earn
# Correct: False
#
# Sentence: that which my son himself indicatedthat of the cupboard of
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: i had the hint from holmes that this
# Predicted: man
# Actual: smoothfaced
# Correct: False
#
# Sentence: forward with a lantern in one hand and a
# Predicted: little
# Actual: weapon
# Correct: False
#
# Sentence: habits he
# Predicted: was
# Actual: learned
# Correct: False
#
# Sentence: which we
# Predicted: shall
# Actual: all
# Correct: False
#
# Sentence: they found the dead body stretched out upon the
# Predicted: table
# Actual: grass
# Correct: False
#
# Sentence: hydraulic engineer left his
# Predicted: head
# Actual: lodgings
# Correct: False
#
# Sentence: you will
# Predicted: be
# Actual: see
# Correct: False
#
# Sentence: like to see the solution of so
# Predicted: i
# Actual: tangled
# Correct: False
#
# Sentence: think that i have
# Predicted: been
# Actual: seen
# Correct: False
#
# Sentence: you mr
# Predicted: holmes
# Actual: holmes
# Correct: True
#
# Sentence: oh yes i know that i
# Predicted: was
# Actual: have
# Correct: False
#
# Sentence: in my private safe and turned once more
# Predicted: than
# Actual: to
# Correct: False
#
# Sentence: teetotaler there was no other woman
# Predicted: to
# Actual: and
# Correct: False
#
# Sentence: to give him an advance upon
# Predicted: the
# Actual: his
# Correct: False
#
# Sentence: intrusted to me i hardened my heart
# Predicted: to
# Actual: and
# Correct: False
#
# Sentence: night dr roylott
# Predicted: is
# Actual: had
# Correct: False
#
# Sentence: why i wonder at that for you are eligible yourself
# Predicted: to
# Actual: for
# Correct: False
#
# Sentence: you quite
# Predicted: so
# Actual: follow
# Correct: False
#
# Sentence: exceptionally strong in the fingers it
# Predicted: was
# Actual: would
# Correct: False
#
# Sentence: fitted with a cap at either end to make it selflighting your
# Predicted: son
# Actual: task
# Correct: False
#
# Sentence: like to chat this little matter over
# Predicted: the
# Actual: with
# Correct: False
#
# Sentence: look here watson he said when the cloth was cleared just
# Predicted: as
# Actual: sit
# Correct: False
#
# Sentence: him that he was a prisoner he remarked that
# Predicted: he
# Actual: he
# Correct: True
#
# Sentence: agitation her face all drawn and grey with
# Predicted: a
# Actual: restless
# Correct: False
#
# Sentence: where is
# Predicted: a
# Actual: it
# Correct: False
#
# Sentence: there is a wellknown agency for
# Predicted: the
# Actual: governesses
# Correct: False
#
# Sentence: his known eccentricity brought in a verdict of suicide
# Predicted: in
# Actual: but
# Correct: False
#
# Sentence: what it was that
# Predicted: i
# Actual: frightened
# Correct: False
#
# Sentence: holmes
# Predicted: and
# Actual: i
# Correct: False
#
# Sentence: and now a word
# Predicted: of
# Actual: as
# Correct: False
#
# Sentence: tell me broke in the engineer is dr becher a
# Predicted: little
# Actual: german
# Correct: False
#
# Sentence: simple that i could
# Predicted: not
# Actual: easily
# Correct: False
#
# Sentence: you didnt know this dead man mccarthy he was a devil
# Predicted: of
# Actual: incarnate
# Correct: False
#
# Sentence: he is so cunning that i never know when i am safe from
# Predicted: the
# Actual: him
# Correct: False
#
# Sentence: hair too as he swept off his
# Predicted: head
# Actual: very
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: must
# Correct: False
#
# Sentence: the lady loves her husband she does not love
# Predicted: to
# Actual: your
# Correct: False
#
# Sentence: goodevening mr james windibank
# Predicted: i
# Actual: said
# Correct: False
#
# Sentence: sufferer it was
# Predicted: a
# Actual: not
# Correct: False
#
# Sentence: box
# Predicted: the
# Actual: of
# Correct: False
#
# Sentence: crowder a gamekeeper in the employ of
# Predicted: the
# Actual: mr
# Correct: False
#
# Sentence: drink and that a ladder should be ready at the moment when
# Predicted: i
# Actual: your
# Correct: False
#
# Sentence: complete manner
# Predicted: and
# Actual: one
# Correct: False
#
# Sentence: the bumping of the road was exchanged for the crisp
# Predicted: of
# Actual: smoothness
# Correct: False
#
# Sentence: that is not quite so common is it
# Predicted: is
# Actual: ah
# Correct: False
#
# Sentence: oh certainly if it would
# Predicted: be
# Actual: give
# Correct: False
#
# Sentence: but without his collar or
# Predicted: his
# Actual: tie
# Correct: False
#
# Sentence: now as safe as if it were
# Predicted: to
# Actual: in
# Correct: False
#
# Sentence: witness it is really impossible for me to tell you i can
# Predicted: see
# Actual: assure
# Correct: False
#
# Sentence: dundas separation case
# Predicted: i
# Actual: and
# Correct: False
#
# Sentence: early days of my association with holmes when we were
# Predicted: to
# Actual: sharing
# Correct: False
#
# Sentence: pew handed it up to her again and it did not
# Predicted: know
# Actual: appear
# Correct: False
#
# Sentence: but you
# Predicted: are
# Actual: are
# Correct: True
#
# Sentence: listened with a frowning
# Predicted: face
# Actual: brow
# Correct: False
#
# Sentence: and now i have a very
# Predicted: good
# Actual: strange
# Correct: False
#
# Sentence: told me and
# Predicted: i
# Actual: it
# Correct: False
#
# Sentence: earth into
# Predicted: the
# Actual: bricks
# Correct: False
#
# Sentence: were only two which i was the means of introducing
# Predicted: that
# Actual: to
# Correct: False
#
# Sentence: gather from that womans appearance
# Predicted: was
# Actual: describe
# Correct: False
#
# Sentence: given prominence not
# Predicted: a
# Actual: so
# Correct: False
#
# Sentence: just as he was in his bare feet opened the window sprang out
# Predicted: the
# Actual: into
# Correct: False
#
# Sentence: words i
# Predicted: have
# Actual: rushed
# Correct: False
#
# Sentence: get back into your chair said holmes
# Predicted: i
# Actual: sternly
# Correct: False
#
# Sentence: dashing never calls less than once a day and often twice
# Predicted: in
# Actual: he
# Correct: False
#
# Sentence: these results you are unable to
# Predicted: be
# Actual: see
# Correct: False
#
# Sentence: i bent over her she suddenly shrieked out
# Predicted: of
# Actual: in
# Correct: False
#
# Sentence: identity of the disappearing
# Predicted: of
# Actual: bridegroom
# Correct: False
#
# Sentence: real occupation my dear wife knew that i had
# Predicted: been
# Actual: business
# Correct: False
#
# Sentence: its light i saw that the black ceiling was coming
# Predicted: in
# Actual: down
# Correct: False
#
# Sentence: as he spoke he drew the dogwhip
# Predicted: of
# Actual: swiftly
# Correct: False
#
# Sentence: i can only claim the merit that i instantly reconsidered my
# Predicted: own
# Actual: position
# Correct: False
#
# Sentence: and very wet it seems to have made you
# Predicted: a
# Actual: said
# Correct: False
#
# Sentence: she was walking
# Predicted: to
# Actual: in
# Correct: False
#
# Sentence: and
# Predicted: i
# Actual: alert
# Correct: False
#
# Sentence: the moonlight sir george
# Predicted: the
# Actual: burnwell
# Correct: False
#
# Sentence: shabbygenteel place where
# Predicted: i
# Actual: four
# Correct: False
#
# Sentence: half an hour i
# Predicted: have
# Actual: sat
# Correct: False
#
# Sentence: with an ounce of shag
# Predicted: and
# Actual: tobacco
# Correct: False
#
# Sentence: i walked round the corner saw the city and
# Predicted: the
# Actual: suburban
# Correct: False
#
# Sentence: he cant
# Predicted: be
# Actual: lie
# Correct: False
#
# Sentence: her over
# Predicted: the
# Actual: with
# Correct: False
#
# Sentence: he seems
# Predicted: to
# Actual: a
# Correct: False
#
# Sentence: than the banker had done in the morning
# Predicted: of
# Actual: and
# Correct: False
#
# Sentence: lived generally in
# Predicted: the
# Actual: good
# Correct: False
#
# Sentence: danger what danger do you
# Predicted: have
# Actual: foresee
# Correct: False
#
# Sentence: work he remarked so i think watson
# Predicted: that
# Actual: that
# Correct: True
#
# Sentence: stairs the bang of a door and the crisp rattle of
# Predicted: the
# Actual: running
# Correct: False
#
# Sentence: much said he have you ever observed that
# Predicted: i
# Actual: his
# Correct: False
#
# Sentence: case i can
# Predicted: see
# Actual: make
# Correct: False
#
# Sentence: then we can hardly get there before
# Predicted: the
# Actual: midnight
# Correct: False
#
# Sentence: seem to have quite a suite
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: brother your father
# Predicted: was
# Actual: whence
# Correct: False
#
# Sentence: lover extinguishes all other
# Predicted: and
# Actual: loves
# Correct: False
#
# Sentence: medical
# Predicted: of
# Actual: profession
# Correct: False
#
# Sentence: horse was fresh and glossy
# Predicted: with
# Actual: when
# Correct: False
#
# Sentence: leaning back in his
# Predicted: hand
# Actual: chair
# Correct: False
#
# Sentence: that he threatened to raise a scandal which would convulse
# Predicted: to
# Actual: the
# Correct: False
#
# Sentence: and his elbows upon
# Predicted: the
# Actual: his
# Correct: False
#
# Sentence: he is as puzzled as everyone else he is
# Predicted: a
# Actual: not
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: entered
# Correct: False
#
# Sentence: brother your father whence it will
# Predicted: be
# Actual: no
# Correct: False
#
# Sentence: and brought miss hunter down from london in order to
# Predicted: the
# Actual: get
# Correct: False
#
# Sentence: swear and that it was a sign of his passion mother was all
# Predicted: the
# Actual: in
# Correct: False
#
# Sentence: you did doctor but none the
# Predicted: matter
# Actual: less
# Correct: False
#
# Sentence: word to either of us but
# Predicted: i
# Actual: she
# Correct: False
#
# Sentence: is not
# Predicted: a
# Actual: the
# Correct: False
#
# Sentence: that foul tongue i did it mr
# Predicted: holmes
# Actual: holmes
# Correct: True
#
# Sentence: i tell you that it is friday man your wife
# Predicted: is
# Actual: has
# Correct: False
#
# Sentence: cheetah and a baboon
# Predicted: man
# Actual: which
# Correct: False
#
# Sentence: terse and to the point
# Predicted: of
# Actual: remarked
# Correct: False
#
# Sentence: come upon my
# Predicted: own
# Actual: father
# Correct: False
#
# Sentence: least there was a strange contrast between the sweet promise
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: holding
# Predicted: and
# Actual: the
# Correct: False
#
# Sentence: fire looks very seasonable in
# Predicted: the
# Actual: this
# Correct: False
#
# Sentence: i have here four letters which purport to come from the missing
# Predicted: of
# Actual: man
# Correct: False
#
# Sentence: subtle enough and horrible enough
# Predicted: to
# Actual: when
# Correct: False
#
# Sentence: in this sinister way i came into my inheritance you will ask
# Predicted: me
# Actual: me
# Correct: True
#
# Sentence: will
# Predicted: be
# Actual: know
# Correct: False
#
# Sentence: the
# Predicted: other
# Actual: man
# Correct: False
#
# Sentence: been the herald of her own death
# Predicted: and
# Actual: i
# Correct: False
#
# Sentence: he came down into
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: stillness that
# Predicted: i
# Actual: we
# Correct: False
#
# Sentence: the halfclad
# Predicted: of
# Actual: stableboy
# Correct: False
#
# Sentence: knew that so astute a villain would see that
# Predicted: i
# Actual: our
# Correct: False
#
# Sentence: then comes
# Predicted: to
# Actual: our
# Correct: False
#
# Sentence: service
# Predicted: and
# Actual: and
# Correct: True
#
# Sentence: bloodstains upon his right shirtsleeve but
# Predicted: i
# Actual: he
# Correct: False
#
# Sentence: weddingdress of watered silk a pair of white satin
# Predicted: and
# Actual: shoes
# Correct: False
#
# Sentence: would bring me down to your
# Predicted: own
# Actual: help
# Correct: False
#
# Sentence: my judgment the fourth
# Predicted: was
# Actual: smartest
# Correct: False
#
# Sentence: we
# Predicted: shall
# Actual: have
# Correct: False
#
# Sentence: it was with his
# Predicted: head
# Actual: barmaid
# Correct: False
#
# Sentence: no if she can come to winchester to
# Predicted: be
# Actual: meet
# Correct: False
#
# Sentence: doubt
# Predicted: and
# Actual: that
# Correct: False
#
# Sentence: wear
# Predicted: and
# Actual: a
# Correct: False
#
# Sentence: pushed
# Predicted: and
# Actual: him
# Correct: False
#
# Sentence: gale and the creaking of an old house
# Predicted: of
# Actual: i
# Correct: False
#
# Sentence: heard the rush of steps below and
# Predicted: the
# Actual: only
# Correct: False
#
# Sentence: chatting about
# Predicted: the
# Actual: her
# Correct: False
#
# Sentence: with an oath tell mary that i shall want a
# Predicted: little
# Actual: fire
# Correct: False
#
# Sentence: made quite a little detour into the meadow lestrade and i
# Predicted: have
# Actual: walked
# Correct: False
#
# Sentence: that therefore the
# Predicted: man
# Actual: deceased
# Correct: False
#
# Sentence: i
# Predicted: have
# Actual: took
# Correct: False
#
# Sentence: a whitewashed corridor with a line
# Predicted: of
# Actual: of
# Correct: True
#
# Sentence: at the time and
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: uffa and finally of the camberwell poisoning case in the
# Predicted: other
# Actual: latter
# Correct: False
#
# Sentence: to me no
# Predicted: i
# Actual: sir
# Correct: False
#
# Sentence: with all the
# Predicted: matter
# Actual: readers
# Correct: False
#
# Sentence: he looked at me i read suspicion
# Predicted: and
# Actual: there
# Correct: False
#
# Sentence: there through the rifts of the clouds holmes
# Predicted: and
# Actual: drove
# Correct: False
#
# Sentence: it looks newer than the
# Predicted: other
# Actual: other
# Correct: True
#
# Sentence: a step in the
# Predicted: house
# Actual: passage
# Correct: False
#
# Sentence: cheetah and
# Predicted: the
# Actual: a
# Correct: False
#
# Sentence: your patience there came a night when
# Predicted: i
# Actual: he
# Correct: False
#
# Sentence: which are very distinct and a few
# Predicted: moments
# Actual: others
# Correct: False
#
# Sentence: groundfloor and
# Predicted: i
# Actual: i
# Correct: True
#
# Sentence: approached it i heard the sharp rattling of a chain
# Predicted: and
# Actual: and
# Correct: True
#
# Sentence: in order that he might solder the second bar of
# Predicted: the
# Actual: the
# Correct: True
#
# Sentence: it is not cold which makes
# Predicted: the
# Actual: me
# Correct: False
#
# Sentence: the middle of a sentence he ordered me to
# Predicted: be
# Actual: cease
# Correct: False
#
# Sentence: either
# Predicted: side
# Actual: shoulder
# Correct: False
#
# Sentence: i have
# Predicted: been
# Actual: been
# Correct: True
#
# Sentence: myself liking to break in upon his
# Predicted: head
# Actual: thoughts
# Correct: False
#
# Sentence: dock and found that she had been taken down the river by the
# Predicted: other
# Actual: early
# Correct: False
#
# Sentence: me and i on
# Predicted: the
# Actual: you
# Correct: False
#
# Sentence: standing in the
# Predicted: room
# Actual: aperture
# Correct: False
#
# Sentence: there
# Predicted: was
# Actual: has
# Correct: False
#
# Sentence: he stood said holmes to the left of the doorthat
# Predicted: was
# Actual: is
# Correct: False
#
# Sentence: tell us makes the matter fairly clear and that i can deduce all
# Predicted: the
# Actual: that
# Correct: False
#
# Sentence: must choose our positions these are
# Predicted: the
# Actual: daring
# Correct: False
#
# Sentence: he snatched it from her
# Predicted: own
# Actual: in
# Correct: False

# %%
# Generate predictions
def predict_next_words(model, tokenizer, seed_text, next_words):
    for _ in range(next_words):
        token_list = [word_to_index[word] for word in tokenize(seed_text)]
        token_list = np.pad(token_list, (max_sequence_len - len(token_list), 0), mode='constant')
        token_list = torch.tensor(token_list[-max_sequence_len+1:], dtype=torch.long).unsqueeze(0)

        with torch.no_grad():
            predicted = model(token_list).argmax(dim=1).item()

        output_word = index_to_word[predicted]
        seed_text += " " + output_word

    return seed_text

seed_text = "i do not know if i have been a"
next_words = 10
print(predict_next_words(model, word_to_index, seed_text, next_words))
