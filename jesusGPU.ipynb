# %%
pip install tensorflow

# %%
pip install torchtext

# %%
pip install torch torchvision

# %%
pip install nltk

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelBinarizer
import nltk
from nltk.tokenize import word_tokenize
# Read the text file
with open('./data/sherlock-holm.es_stories_plain-text_advs.txt', 'r', encoding='utf-8') as file:
    text = file.read()
    text = text.lower()

# %%
print(text)

# %%
tokens = word_tokenize(text)
vocabulary = set(tokens)
total_words = len(vocabulary) + 1

word_to_idx = {word:idx for idx, word in enumerate(vocabulary)}

print(f"total_words: {total_words}")
print("Índice de palabras:", word_to_idx)
# Out:
# total_words: 8384
# Índice de palabras: {"'hullo": 0, 'backward': 1, 'esq': 2, 'trusted': 3, 'adjective': 4, 'snigger': 5, 'quivering': 6, 'chose': 7, 'simon': 8, 'recovering': 9, 'fruitless': 10, 'prompt': 11, 'loftily': 12, 'ascended': 13, 'must': 14, 'cuts': 15, 'cloud-wreaths': 16, 'seat': 17, 'sweet': 18, 'faint': 19, 'liver': 20, 'themselves': 21, 'discover': 22, 'vulnerable': 23, 'commonplaces': 24, 'occasionally': 25, 'waterproof': 26, 'labour': 27, 'sight': 28, 'wondering': 29, 'setting': 30, 'upset': 31, 'guilt': 32, 'army': 33, 'orgies': 34, 'doing': 35, 'coincidences': 36, 'impossibility': 37, 'pittance': 38, 'fund': 39, 'glimpses': 40, 'pulled': 41, 'wickedness': 42, 'overtaken': 43, 'important': 44, 'grizzled': 45, 'stories': 46, 'satisfy': 47, 'daubing': 48, 'stevenson': 49, 'glanced': 50, 'hotel': 51, 'tear': 52, 'waxed': 53, 'killed': 54, "man's": 55, 'level': 56, 'gesticulating': 57, 'cast-off': 58, 'bed': 59, 'parley': 60, 'noose': 61, 'sucked': 62, 'attired': 63, 'carolinas': 64, 'them': 65, 'earth': 66, 'ingenious': 67, 'languid': 68, 'silence': 69, "l'homme": 70, 'glare': 71, 'vehicle': 72, 'slipping': 73, 'gale': 74, 'recall': 75, 'roofs': 76, 'court-yard': 77, 'pipe-rack': 78, 'pirates': 79, 'particularly': 80, 'changing': 81, 'mention': 82, 'waited': 83, 'eligible': 84, 'kneeling': 85, 'perpetrated': 86, 'reasonable': 87, 'forces': 88, 'emigrated': 89, 'concerned': 90, 'flock': 91, "'eg": 92, 'given': 93, 'continue': 94, 'wall': 95, 'forefingers': 96, 'dishonoured': 97, 'stretching': 98, "'american": 99, 'clergyman': 100, 'second': 101, 'dawn': 102, 'reparation': 103, 'fidelity': 104, 'momentary': 105, 'continued': 106, 'arc-and-compass': 107, 'spun': 108, 'pauper': 109, 'gordon': 110, 'slippery': 111, 'major-general': 112, 'fast': 113, 'incomplete': 114, 'hitherto': 115, 'softened': 116, 'nay': 117, 'percy': 118, 'clear': 119, 'blazing': 120, 'rate': 121, 'screen': 122, 'gin-shop': 123, 'gong': 124, 'remarked': 125, 'assembled': 126, 'voilà': 127, 'lurking': 128, 'mornings': 129, 'windfall': 130, 'concisely': 131, 'tack': 132, 'afraid': 133, 'betray': 134, 'had': 135, 'apprenticed': 136, "'singular": 137, 'goes': 138, 'hoped': 139, 'laughing': 140, '1000': 141, 'schemer': 142, "i'd": 143, 'overdid': 144, 'solder': 145, 'thinness': 146, 'cleared': 147, 'greenwich': 148, "'encyclopaedia": 149, 'serpent': 150, 'cane': 151, 'earth-smelling': 152, 'fed': 153, 'pluck': 154, 'burnwell': 155, 'eastern': 156, 'footsteps': 157, 'half-buttoned': 158, 'perspired': 159, 'stabbed': 160, 'wedding': 161, 'variants': 162, 'discoloured': 163, 'hope': 164, "'and": 165, "'can": 166, 'inhabited': 167, 'ay': 168, 'seemed': 169, 'chairman': 170, 'conclusive': 171, "'papier": 172, 'perfectly': 173, 'big': 174, 'alternately': 175, 'depose': 176, 'double-bedded': 177, 'forbidden': 178, 'foreigner': 179, 'note-book': 180, 'far-gone': 181, "'ll": 182, 'statements': 183, 'act': 184, 'splendour': 185, 'card-case': 186, 'mexico': 187, 'cravat': 188, 'than': 189, 'rising': 190, 'travellers': 191, 'bend': 192, 'chances': 193, 'unfettered': 194, 'rickety': 195, 'kent': 196, 'affectionate': 197, 'game': 198, 'impossible': 199, 'puzzle': 200, 'soaked': 201, 'capital': 202, 'glamour': 203, 'shopping': 204, 'thoughts': 205, 'lasting': 206, 'fowler': 207, 'disappointed': 208, 'eighteen': 209, 'sufficient': 210, 'shamefaced': 211, 'produced': 212, 'good-evening': 213, 'legal': 214, 'woven': 215, 'anstruther': 216, 'path': 217, 'swept': 218, 'opposed': 219, 'wonder': 220, 'diary': 221, 'consult': 222, 'thickening': 223, 'same': 224, 'feature': 225, 'bet': 226, 'meets': 227, 'goodge': 228, 'series': 229, 'grip': 230, 'ramblings': 231, 'bare': 232, 'hinting': 233, 'weedy': 234, 'dollars': 235, 'hafiz': 236, 'litter': 237, 'sluggishly': 238, 'attempting': 239, 'term': 240, 'breakfast-room': 241, 'ungenerously': 242, 'peculiarly': 243, 'boisterous': 244, 'expensive': 245, 'semicircle': 246, 'proved': 247, 'sums': 248, 'bandy': 249, 'perplexing': 250, 'out-house': 2 ...

# %%
input_sequences = []
for line in text.split('\n'):
    line_list = line.rstrip(",.;:").split(' ')
    token_list = []
    for char in line_list:
        if char in word_to_idx.keys():
            token_list.append(word_to_idx[char])

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
# Imprimiendo las secuencias de n-gramas
print(f"Secuencias de n-gramas: {input_sequences[:5]}")

# %%
from torch.nn.utils.rnn import pad_sequence

# %%
# Determinamos la longitud máxima de las secuencias.
max_sequence_len = max(len(seq) for seq in input_sequences)

# Añadimos padding al principio de cada secuencia.
padded_sequences = []
for seq in input_sequences:
    num_padding = max_sequence_len - len(seq)
    padded_seq = [0] * num_padding + seq
    padded_sequences.append(padded_seq)

# Convertimos las secuencias en tensores.
tensor_sequences = torch.tensor(padded_sequences)

# %%
print(f"max_sequence_len: {max_sequence_len}")
print(f"Secuencias de n-gramas: {tensor_sequences[:5]}")

# %%
X = tensor_sequences[:, :-1]
y = tensor_sequences[:, -1]

# %%
print(X)
print(y)

# %%
import torch.nn.functional as F

# %%
# Convertir las etiquetas a one-hot encoding
num_classes = y.max().item() + 1  # Determinar el número de clases
y = F.one_hot(y, num_classes=num_classes)

# %%
print("Secuencias con padding (X):")
print(X)
print("Etiquetas (y) en one-hot encoding:")
print(y)

# %%
class TextDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.long)
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
dataset = TextDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# C:\Users\Alvaro\AppData\Local\Temp\ipykernel_27688\3547505943.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.X = torch.tensor(X, dtype=torch.long)

# %%
class LSTMModel(nn.Module):
    def __init__(self, total_words, embedding_dim, hidden_dim, output_dim):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(total_words, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.embedding(x)
        lstm_out , _ = self.lstm(x)
        lstm_out = lstm_out[:, -1, :]
        x = self.fc(lstm_out)
        x = self.softmax(x)
        return x

# %%
model = LSTMModel(total_words, 100, 150, total_words).cuda()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def train_model(model, dataloader, criterion, optimizer, epochs):
    model.train()
    for epoch in range(epochs):
        for X_batch, y_batch in dataloader:
            X_batch, y_batch = X_batch.cuda(), y_batch.cuda()  # Mover datos a la GPU
            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, torch.max(y_batch, 1)[1])
            loss.backward()
            optimizer.step()
        print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')

# %%
import torch
torch.cuda.is_available()

a=torch.FloatTensor([1.0,2.0]).cuda()

a.device

torch.manual_seed(32)


next(model.parameters()).is_cuda
# Out:
# True

# %%
gpumodel = model.cuda()

# %%
train_model(model, dataloader, criterion, optimizer, epochs=100)
# Out:
# Epoch 1/100, Loss: 8.995824813842773
# Epoch 2/100, Loss: 8.995824813842773
# Epoch 3/100, Loss: 8.880439758300781
# Epoch 4/100, Loss: 8.95736312866211
# Epoch 5/100, Loss: 8.995824813842773
# Epoch 6/100, Loss: 8.995824813842773
# Epoch 7/100, Loss: 8.95736312866211
# Epoch 8/100, Loss: 8.995824813842773
# Epoch 9/100, Loss: 9.034285545349121
# Epoch 10/100, Loss: 8.95736312866211
# Epoch 11/100, Loss: 8.918901443481445
# Epoch 12/100, Loss: 8.995824813842773
# Epoch 13/100, Loss: 8.995824813842773
# Epoch 14/100, Loss: 8.95736312866211
# Epoch 15/100, Loss: 9.034285545349121
# Epoch 16/100, Loss: 8.95736312866211
# Epoch 17/100, Loss: 9.034285545349121
# Epoch 18/100, Loss: 9.034285545349121
# Epoch 19/100, Loss: 8.995824813842773
# Epoch 20/100, Loss: 8.918901443481445
# Epoch 21/100, Loss: 8.995824813842773
# Epoch 22/100, Loss: 8.995824813842773
# Epoch 23/100, Loss: 8.95736312866211
# Epoch 24/100, Loss: 8.95736312866211
# Epoch 25/100, Loss: 8.880439758300781
# Epoch 26/100, Loss: 8.880439758300781
# Epoch 27/100, Loss: 8.95736312866211
# Epoch 28/100, Loss: 9.034285545349121
# Epoch 29/100, Loss: 8.880439758300781
# Epoch 30/100, Loss: 8.918901443481445
# Epoch 31/100, Loss: 8.995824813842773
# Epoch 32/100, Loss: 8.995824813842773
# Epoch 33/100, Loss: 9.034285545349121
# Epoch 34/100, Loss: 9.034285545349121
# Epoch 35/100, Loss: 8.995824813842773
# Epoch 36/100, Loss: 8.995824813842773
# Epoch 37/100, Loss: 8.95736312866211
# Epoch 38/100, Loss: 8.95736312866211
# Epoch 39/100, Loss: 8.995824813842773
# Epoch 40/100, Loss: 8.995824813842773
# Epoch 41/100, Loss: 8.880439758300781
# Epoch 42/100, Loss: 8.995824813842773
# Epoch 43/100, Loss: 8.995824813842773
# Epoch 44/100, Loss: 8.995824813842773
# Epoch 45/100, Loss: 8.995824813842773
# Epoch 46/100, Loss: 8.995824813842773
# Epoch 47/100, Loss: 8.995824813842773
# Epoch 48/100, Loss: 8.95736312866211
# Epoch 49/100, Loss: 8.995824813842773
# Epoch 50/100, Loss: 9.034285545349121
# Epoch 51/100, Loss: 8.995824813842773
# Epoch 52/100, Loss: 8.95736312866211
# Epoch 53/100, Loss: 8.995824813842773
# Epoch 54/100, Loss: 8.880439758300781
# Epoch 55/100, Loss: 8.995824813842773
# Epoch 56/100, Loss: 9.034285545349121
# Epoch 57/100, Loss: 8.918901443481445
# Epoch 58/100, Loss: 8.95736312866211
# Epoch 59/100, Loss: 8.995824813842773
# Epoch 60/100, Loss: 8.918901443481445
# Epoch 61/100, Loss: 8.95736312866211
# Epoch 62/100, Loss: 8.918901443481445
# Epoch 63/100, Loss: 8.95736312866211
# Epoch 64/100, Loss: 8.918901443481445
# Epoch 65/100, Loss: 8.918901443481445
# Epoch 66/100, Loss: 8.995824813842773
# Epoch 67/100, Loss: 8.880439758300781
# Epoch 68/100, Loss: 8.918901443481445
# Epoch 69/100, Loss: 8.995824813842773
# Epoch 70/100, Loss: 8.95736312866211
# Epoch 71/100, Loss: 9.034285545349121
# Epoch 72/100, Loss: 9.034285545349121
# Epoch 73/100, Loss: 8.995824813842773
# Epoch 74/100, Loss: 8.841978073120117
# Epoch 75/100, Loss: 8.918901443481445
# Epoch 76/100, Loss: 8.918901443481445
# Epoch 77/100, Loss: 9.034285545349121
# Epoch 78/100, Loss: 8.995824813842773
# Epoch 79/100, Loss: 8.95736312866211
# Epoch 80/100, Loss: 8.880439758300781
# Epoch 81/100, Loss: 9.034285545349121
# Epoch 82/100, Loss: 8.995824813842773
# Epoch 83/100, Loss: 9.034285545349121
# Epoch 84/100, Loss: 8.95736312866211
# Epoch 85/100, Loss: 9.034285545349121
# Epoch 86/100, Loss: 8.995824813842773
# Epoch 87/100, Loss: 8.995824813842773
# Epoch 88/100, Loss: 8.995824813842773
# Epoch 89/100, Loss: 8.918901443481445
# Epoch 90/100, Loss: 9.034285545349121
# Epoch 91/100, Loss: 8.995824813842773
# Epoch 92/100, Loss: 8.995824813842773
# Epoch 93/100, Loss: 8.995824813842773
# Epoch 94/100, Loss: 8.95736312866211
# Epoch 95/100, Loss: 8.995824813842773
# Epoch 96/100, Loss: 8.918901443481445
# Epoch 97/100, Loss: 8.880439758300781
# Epoch 98/100, Loss: 8.995824813842773
# Epoch 99/100, Loss: 8.880439758300781
# Epoch 100/100, Loss: 8.95736312866211

# %%
model.eval()
#Guardar modelo
torch.save(model.state_dict(), "model.pth")

#Guardar tokenizer
import pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(word_to_idx, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
model.load_state_dict(torch.load('model.pth'))
# Out:
# <All keys matched successfully>

# %%
# Texto inicial y número de palabras a predecir
seed_text = "I will leave if they"
next_words = 3

idx_to_word = {idx: word for word, idx in word_to_idx.items()}

# Tokenizamos el seed_text y lo convertimos a índices
tokens = word_tokenize(seed_text)
input_sequence = [word_to_idx[word] for word in tokens if word in word_to_idx]

# Generamos las siguientes palabras
model.eval()  # Configuramos el modelo en modo evaluación
for _ in range(next_words):
    # Convertimos la secuencia de entrada a tensor y añadimos una dimensión
    input_tensor = torch.tensor(input_sequence).unsqueeze(0)

    # Realizamos la predicción con el modelo
    with torch.no_grad():
        output = model(input_tensor)

    # Obtenemos el índice de la palabra predicha
    predicted_idx = torch.argmax(output, dim=1).item()

    # Añadimos la palabra predicha a la secuencia de entrada
    input_sequence.append(predicted_idx)

    # Añadimos la palabra predicha al texto semilla
    word = idx_to_word[predicted_idx]
    seed_text += " " + word

print(seed_text)
# Out:
# I will leave if they the the the
